# %% [markdown]
# ## 파이썬 고급
# # Matplotlib 를 활용한 도식화와 시각화
# ---
# ## matplotlib 기초

# %% [markdown]
# ### 시각화의 중요성과 matplotlib
# - 인간은 가장 시각 능력이 뛰어난 동물 중의 하나이다.
# - 하지만 인간의 수치 계산 능력은 본능이 아니다. (언어의 발달로 인한 논리 능력의 확장임)
# - 이런 점들이 인간이 아직까지 인공지능에 비해 시각적 판단이 뛰어난 이유이다.
# - 시각 능력은 다른 말로 하면 **패턴인식** 능력이다. 빛의 분포로 생기는 시각 패턴을 인간은 너무나 쉽게 알아 볼 수 있다.
# - 이러한 인간의 능력을 최대한 발휘하기 위해서 숫자로 되어 있는 데이터를 시각화 하여야 한다.
# - 제공받은 데이터의 **특성을 분석**하기 위해서 뿐만 아니라, **결과를 설명**하기 위해서 시각화는 아주 중요하다.
# - matplotlib 는 파이썬의 시각화 도구이다.
# - matplotlib 는 MATLAB 의 시각화 기능을 참고하여 만들어졌다.
# - matplotlib 는 3차원 시각화 도구를 제공하지만 평면 상에서 3차원 도표는 알아보기 쉽지 않으므로, 대부분의 시각화 기능은 2차원을 위주로 한다.

# %% [markdown]
# ### 참고 자료
# - 홈페이지 : https://matplotlib.org/
# - 튜토리얼 : https://matplotlib.org/tutorials/introductory/pyplot.html
# - API : https://matplotlib.org/api/index.html
# - 예제 : https://matplotlib.org/tutorials/index.html#introductory

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([101, -3, 77, 0, 15, 39, -22])
#plt.ylim(0,20)

# %%
plt.plot(range(3,77,5))

# %%
plt.show()

# %% [markdown]
# **[주의]**
# - %pylab inline 또는 %matplotlib inline 을 실행하면 ipython 과 쥬피터 노트북에서 plt.show() 를 실행하지 않아도 되고 도표가 실행창에 포함된다.

# %%
#%pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.plot([101,201,301,401])

# %%
plt.plot([1,2,3,4])
plt.plot([40,30,20,10])
plt.legend(['a','b'])

# %%
plt.plot([1,2,3,4], label='up')
plt.plot([4,3,2,1], label='down')
plt.legend(loc='center right')

# %%
plt.plot([1,2,3,4])
plt.plot([4,3,2,1])
plt.legend(['up','down'],loc='center right')

# %%
help(plt.legend)
# Out:
# Help on function legend in module matplotlib.pyplot:
#
# legend(*args, **kwargs)
#     Places a legend on the axes.
#
#     Call signatures::
#
#         legend()
#         legend(labels)
#         legend(handles, labels)
#
#     The call signatures correspond to three different ways how to use
#     this method.
#
#     **1. Automatic detection of elements to be shown in the legend**
#
#     The elements to be added to the legend are automatically determined,
#     when you do not pass in any extra arguments.
#
#     In this case, the labels are taken from the artist. You can specify
#     them either at artist creation or by calling the
#     :meth:`~.Artist.set_label` method on the artist::
#
#         line, = ax.plot([1, 2, 3], label='Inline label')
#         ax.legend()
#
#     or::
#
#         line.set_label('Label via method')
#         line, = ax.plot([1, 2, 3])
#         ax.legend()
#
#     Specific lines can be excluded from the automatic legend element
#     selection by defining a label starting with an underscore.
#     This is default for all artists, so calling `Axes.legend` without
#     any arguments and without setting the labels manually will result in
#     no legend being drawn.
#
#
#     **2. Labeling existing plot elements**
#
#     To make a legend for lines which already exist on the axes
#     (via plot for instance), simply call this function with an iterable
#     of strings, one for each legend item. For example::
#
#         ax.plot([1, 2, 3])
#         ax.legend(['A simple line'])
#
#     Note: This way of using is discouraged, because the relation between
#     plot elements and labels is only implicit by their order and can
#     easily be mixed up.
#
#
#     **3. Explicitly defining the elements in the legend**
#
#     For full control of which artists have a legend entry, it is possible
#     to pass an iterable of legend artists followed by an iterable of
#     legend labels respectively::
#
#         legend((line1, line2, line3), ('label1', 'label2', 'label3'))
#
#     Parameters
#     ----------
#
#     handles : sequence of `.Artist`, optional
#         A list of Artists (lines, patches) to be added to the legend.
#         Use this together with *labels*, if you need full control on what
#         is shown in the legend and the automatic mechanism described above
#         is not sufficient.
#
#         The length of handles and labels should be the same in this
#         case. If they are not, they are truncated to the smaller length.
#
#     labels : sequence of strings, optional
#         A list of labels to show next to the artists.
#         Use this together with *handles*, if you need full control on what
#         is shown in the legend and the automatic mechanism described above
#         is not sufficient.
#
#     Other Parameters
#     ----------------
#
#     loc : int or string or pair of floats, default: 'upper right'
#         The location of the legend. Possible codes are:
#
#             ===============   =============
#             Location String   Location Code
#             ===============   =============
#             'best'            0
#             'upper right'     1
#             'upper left'      2
#             'lower left'      3
#             'lower right'     4
#             'right'           5
#             'center left'     6
#             'center right'    7
#             'lower center'    8
#             'upper center'    9
#             'center'          10
#             ===============   =============
#
#
#         Alternatively can be a 2-tuple giving ``x, y`` of the lower-left
#         corner of the legend in axes coordinates (in which case
#         ``bbox_to_anchor`` will be ignored).
#
#     bbox_to_anchor : `.BboxBase` or pair of floats
#         Specify any arbitrary location for the legend in `bbox_transform`
#         coordinates (default Axes coordinates).
#
#         For example, to put the legend's upper right hand corner in the
#         center of the axes the following keywords can be used::
#
#            loc='upper right', bbox_to_anchor=(0.5, 0.5)
#
#     ncol : integer
#         The number of columns that the legend has. Default is 1.
#
#     prop : None or :class:`matplotlib.font_manager.FontProperties` or dict
#         The font properties of the legend. If None (default), the current
#         :data:`matplotlib.rcParams` will be used.
#
#     fontsize : int or float or {'xx-small', 'x-small', 'small', 'medium', 'large', 'x-large', 'xx-large'}
#         Controls the font size of the legend. If the value is numeric the
#         size will be the absolute font size in points. String values are
#         relative to the current default font size. This argument is only
#         used if `prop` is not specified.
#
#     numpoints : None or int
#         The number of marker points in the legend when creating a legend
#         entry for a `.Line2D` (line).
#         Default is ``None``, which will take the value from
#         :rc:`legend.numpoints`.
#
#     scatterpoints : None or int
#         The number of marker points in the legend when creating
#         a legend entry for a `.PathCollection` (scatter plot).
#         Default is ``None``, which will take the value from
#         :rc:`legend.scatterpoints`.
#
#     scatteryoffsets : iterable of floats
#         The vertical offset (relative to the font size) for the markers
#         created for a scatter plot legend entry. 0.0 is at the base the
#         legend text, and 1.0 is at the top. To draw all markers at the
#         same height, set to ``[0.5]``. Default is ``[0.375, 0.5, 0.3125]``.
#
#     markerscale : None or int or float
#         The relative size of legend markers compared with the originally
#         drawn ones.
#         Default is ``None``, which will take the value from
#         :rc:`legend.markerscale`.
#
#     markerfirst : bool
#         If *True*, legend marker is placed to the left of the legend label.
#         If *False*, legend marker is placed to the right of the legend
#         label.
#         Default is *True*.
#
#     frameon : None or bool
#         Control whether the legend should be drawn on a patch
#         (frame).
#         Default is ``None``, which will take the value from
#         :rc:`legend.frameon`.
#
#     fancybox : None or bool
#         Control whether round edges should be enabled around the
#         :class:`~matplotlib.patches.FancyBboxPatch` which makes up the
#         legend's background.
#         Default is ``None``, which will take the value from
#         :rc:`legend.fancybox`.
#
#     shadow : None or bool
#         Control whether to draw a shadow behind the legend.
#         Default is ``None``, which will take the value from
#         :rc:`legend.shadow`.
#
#     framealpha : None or float
#         Control the alpha transparency of the legend's background.
#         Default is ``None``, which will take the value from
#         :rc:`legend.framealpha`.  If shadow is activated and
#         *framealpha* is ``None``, the default value is ignored.
#
#     facecolor : None or "inherit" or a color spec
#         Control the legend's background color.
#         Default is ``None``, which will take the value from
#         :rc:`legend.facecolor`.  If ``"inherit"``, it will take
#         :rc:`axes.facecolor`.
#
#     edgecolor : None or "inherit" or a color spec
#         Control the legend's background patch edge color.
#         Default is ``None``, which will take the value from
#         :rc:`legend.edgecolor` If ``"inherit"``, it will take
#         :rc:`axes.edgecolor`.
#
#     mode : {"expand", None}
#         If `mode` is set to ``"expand"`` the legend will be horizontally
#         expanded to fill the axes area (or `bbox_to_anchor` if defines
#         the legend's size).
#
#     bbox_transform : None or :class:`matplotlib.transforms.Transform`
#         The transform for the bounding box (`bbox_to_anchor`). For a value
#         of ``None`` (default) the Axes'
#         :data:`~matplotlib.axes.Axes.transAxes` transform will be used.
#
#     title : str or None
#         The legend's title. Default is no title (``None``).
#
#     borderpad : float or None
#         The fractional whitespace inside the legend border.
#         Measured in font-size units.
#         Default is ``None``, which will take the value from
#         :rc:`legend.borderpad`.
#
#     labelspacing : float or None
#         The vertical space between the legend entries.
#         Measured in font-size units.
#         Default is ``None``, which will take the value from
#         :rc:`legend.labelspacing`.
#
#     handlelength : float or None
#         The length of the legend handles.
#         Measured in font-size units.
#         Default is ``None``, which will take the value from
#         :rc:`legend.handlelength`.
#
#     handletextpad : float or None
#         The pad between the legend handle and text.
#         Measured in font-size units.
#         Default is ``None``, which will take the value from
#         :rc:`legend.handletextpad`.
#
#     borderaxespad : float or None
#         The pad between the axes and legend border.
#         Measured in font-size units.
#         Default is ``None``, which will take the value from
#         :rc:`legend.borderaxespad`.
#
#     columnspacing : float or None
#         The spacing between columns.
#         Measured in font-size units.
#         Default is ``None``, which will take the value from
#         :rc:`legend.columnspacing`.
#
#     handler_map : dict or None
#         The custom dictionary mapping instances or types to a legend
#         handler. This `handler_map` updates the default handler map
#         found at :func:`matplotlib.legend.Legend.get_legend_handler_map`.
#
#     Returns
#     -------
#
#     :class:`matplotlib.legend.Legend` instance
#
#     Notes
#     -----
#
#     Not all kinds of artist are supported by the legend command. See
#     :doc:`/tutorials/intermediate/legend_guide` for details.
#
#     Examples
#     --------
#
#     .. plot:: gallery/api/legend.py

# %%
plt.plot([1,2,3,4], label='up')
plt.plot([4,3,2,1], label='down')
plt.legend(loc='best')
plt.axis([-1,4,0,5])

# %% [markdown]
# - 도표에 제목을 붙이자.

# %%
plt.plot([1,2,3,4], label='up')
plt.plot([4,3,2,1], label='down')
plt.legend(loc='best')
plt.axis([-1,4,0,5])

plt.title('UP and DOWN lines', fontsize=20)
plt.xlabel('X')
plt.ylabel('value', fontsize=50)
# Out:
# Text(0,0.5,'value')

# %% [markdown]
# - 이미지 크기를 변경하자.

# %%
fig = plt.figure(figsize=[12,8])

plt.plot([1,2,3,4], label='up')
plt.plot([4,3,2,1], label='down')
plt.legend(loc='best')
plt.axis('scaled')
plt.axis([-1,4,0,5])
#plt.xlim(-1,4)
#plt.ylim(0,5)

plt.title('UP and DOWN lines', fontsize=20)
plt.xlabel('X')
plt.ylabel('value')

plt.xticks([0, 1.5, 3],['one','1 1/2', 'three'])
plt.yticks(np.arange(1,4.1,0.5))
plt.grid()

# %% [markdown]
# ### plot() 함수
# - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot

# %%
a=np.random.randn(100)

plt.plot(a)
plt.plot(a.cumsum())
plt.legend(['original','cumsum'])

# %%
plt.plot(a, 'b:') # color='b', linestyle='--'
plt.plot(a.cumsum(), 'gD-') # color='red', marker='o', linestyle='-'
plt.legend(['original','cumsum'], loc='best')

# %%
plt.plot(a[:10], 'r^-', linewidth=3, markersize=10)
plt.plot(a[:10], 'g:', drawstyle='steps-post')

# %%
plt.plot([0,1,2,3], label='p1')
plt.plot([1,2,3,4])
plt.plot([2,3,4,5], label='p3')

plt.xticks(range(4),['Jang gil san','hong gil dong','lee soon sin'],rotation=90, ha='center')
plt.legend()

# %% [markdown]
# - plot() 함수에 인자로 목록을 2개 주면, 각각 x축 값과 y축 값이 된다.
# - 위에서 본 것과 같이 인자 하나를 주면 y축 값이다.

# %%
plt.plot([7,3,1,9])
#plt.plot([0,1,2,3], [7,3,1,9])

# %%
plt.plot([1,3,2,4], [1,2,3,4])
plt.axis([0,5,0,5])
# Out:
# [0, 5, 0, 5]

# %%
iris = np.loadtxt('iris.csv', delimiter=',', skiprows=1, usecols=[0,1,2,3])
plt.plot(iris)
# Out:
# [<matplotlib.lines.Line2D at 0x20cd3fcc6a0>,
#  <matplotlib.lines.Line2D at 0x20cd3fcc7f0>,
#  <matplotlib.lines.Line2D at 0x20cd3fcc940>,
#  <matplotlib.lines.Line2D at 0x20cd3fcca90>]

# %%
plt.plot(iris.T, alpha=0.1)
# Out:
# [<matplotlib.lines.Line2D at 0x20cd4224400>,
#  <matplotlib.lines.Line2D at 0x20cd4224550>,
#  <matplotlib.lines.Line2D at 0x20cd42246a0>,
#  <matplotlib.lines.Line2D at 0x20cd42247f0>,
#  <matplotlib.lines.Line2D at 0x20cd4224940>,
#  <matplotlib.lines.Line2D at 0x20cd4224a90>,
#  <matplotlib.lines.Line2D at 0x20cd4224be0>,
#  <matplotlib.lines.Line2D at 0x20cd4224d30>,
#  <matplotlib.lines.Line2D at 0x20cd4224e80>,
#  <matplotlib.lines.Line2D at 0x20cd4224fd0>,
#  <matplotlib.lines.Line2D at 0x20cd42027f0>,
#  <matplotlib.lines.Line2D at 0x20cd422a278>,
#  <matplotlib.lines.Line2D at 0x20cd422a3c8>,
#  <matplotlib.lines.Line2D at 0x20cd422a518>,
#  <matplotlib.lines.Line2D at 0x20cd422a668>,
#  <matplotlib.lines.Line2D at 0x20cd422a7b8>,
#  <matplotlib.lines.Line2D at 0x20cd422a908>,
#  <matplotlib.lines.Line2D at 0x20cd422aa58>,
#  <matplotlib.lines.Line2D at 0x20cd422aba8>,
#  <matplotlib.lines.Line2D at 0x20cd422acf8>,
#  <matplotlib.lines.Line2D at 0x20cd422ae48>,
#  <matplotlib.lines.Line2D at 0x20cd422af98>,
#  <matplotlib.lines.Line2D at 0x20cd422f128>,
#  <matplotlib.lines.Line2D at 0x20cd422f278>,
#  <matplotlib.lines.Line2D at 0x20cd422f3c8>,
#  <matplotlib.lines.Line2D at 0x20cd422f518>,
#  <matplotlib.lines.Line2D at 0x20cd422f668>,
#  <matplotlib.lines.Line2D at 0x20cd422f7b8>,
#  <matplotlib.lines.Line2D at 0x20cd422f908>,
#  <matplotlib.lines.Line2D at 0x20cd422fa58>,
#  <matplotlib.lines.Line2D at 0x20cd422fba8>,
#  <matplotlib.lines.Line2D at 0x20cd422fcf8>,
#  <matplotlib.lines.Line2D at 0x20cd422fe48>,
#  <matplotlib.lines.Line2D at 0x20cd422ff98>,
#  <matplotlib.lines.Line2D at 0x20cd4234128>,
#  <matplotlib.lines.Line2D at 0x20cd4234278>,
#  <matplotlib.lines.Line2D at 0x20cd42343c8>,
#  <matplotlib.lines.Line2D at 0x20cd4234518>,
#  <matplotlib.lines.Line2D at 0x20cd4234668>,
#  <matplotlib.lines.Line2D at 0x20cd42347b8>,
#  <matplotlib.lines.Line2D at 0x20cd4234908>,
#  <matplotlib.lines.Line2D at 0x20cd4234a58>,
#  <matplotlib.lines.Line2D at 0x20cd4234ba8>,
#  <matplotlib.lines.Line2D at 0x20cd4234cf8>,
#  <matplotlib.lines.Line2D at 0x20cd4234e48>,
#  <matplotlib.lines.Line2D at 0x20cd4234f98>,
#  <matplotlib.lines.Line2D at 0x20cd4239128>,
#  <matplotlib.lines.Line2D at 0x20cd4239278>,
#  <matplotlib.lines.Line2D at 0x20cd42393c8>,
#  <matplotlib.lines.Line2D at 0x20cd4239518>,
#  <matplotlib.lines.Line2D at 0x20cd4239668>,
#  <matplotlib.lines.Line2D at 0x20cd42397b8>,
#  <matplotlib.lines.Line2D at 0x20cd4239908>,
#  <matplotlib.lines.Line2D at 0x20cd4239a58>,
#  <matplotlib.lines.Line2D at 0x20cd4239ba8>,
#  <matplotlib.lines.Line2D at 0x20cd4239cf8>,
#  <matplotlib.lines.Line2D at 0x20cd4239e48>,
#  <matplotlib.lines.Line2D at 0x20cd4239f98>,
#  <matplotlib.lines.Line2D at 0x20cd423e128>,
#  <matplotlib.lines.Line2D at 0x20cd423e278>,
#  <matplotlib.lines.Line2D at 0x20cd423e3c8>,
#  <matplotlib.lines.Line2D at 0x20cd423e518>,
#  <matplotlib.lines.Line2D at 0x20cd423e668>,
#  <matplotlib.lines.Line2D at 0x20cd423e7b8>,
#  <matplotlib.lines.Line2D at 0x20cd423e908>,
#  <matplotlib.lines.Line2D at 0x20cd423ea58>,
#  <matplotlib.lines.Line2D at 0x20cd423eba8>,
#  <matplotlib.lines.Line2D at 0x20cd423ecf8>,
#  <matplotlib.lines.Line2D at 0x20cd423ee48>,
#  <matplotlib.lines.Line2D at 0x20cd423ef98>,
#  <matplotlib.lines.Line2D at 0x20cd4244128>,
#  <matplotlib.lines.Line2D at 0x20cd4244278>,
#  <matplotlib.lines.Line2D at 0x20cd42443c8>,
#  <matplotlib.lines.Line2D at 0x20cd4244518>,
#  <matplotlib.lines.Line2D at 0x20cd4244668>,
#  <matplotlib.lines.Line2D at 0x20cd42447b8>,
#  <matplotlib.lines.Line2D at 0x20cd4244908>,
#  <matplotlib.lines.Line2D at 0x20cd4244a58>,
#  <matplotlib.lines.Line2D at 0x20cd4244ba8>,
#  <matplotlib.lines.Line2D at 0x20cd4244cf8>,
#  <matplotlib.lines.Line2D at 0x20cd4244e48>,
#  <matplotlib.lines.Line2D at 0x20cd4244f98>,
#  <matplotlib.lines.Line2D at 0x20cd4249128>,
#  <matplotlib.lines.Line2D at 0x20cd4249278>,
#  <matplotlib.lines.Line2D at 0x20cd42493c8>,
#  <matplotlib.lines.Line2D at 0x20cd4249518>,
#  <matplotlib.lines.Line2D at 0x20cd4249668>,
#  <matplotlib.lines.Line2D at 0x20cd42497b8>,
#  <matplotlib.lines.Line2D at 0x20cd4249908>,
#  <matplotlib.lines.Line2D at 0x20cd4249a58>,
#  <matplotlib.lines.Line2D at 0x20cd4249ba8>,
#  <matplotlib.lines.Line2D at 0x20cd4249cf8>,
#  <matplotlib.lines.Line2D at 0x20cd4249e48>,
#  <matplotlib.lines.Line2D at 0x20cd4249f98>,
#  <matplotlib.lines.Line2D at 0x20cd424e128>,
#  <matplotlib.lines.Line2D at 0x20cd424e278>,
#  <matplotlib.lines.Line2D at 0x20cd424e3c8>,
#  <matplotlib.lines.Line2D at 0x20cd424e518>,
#  <matplotlib.lines.Line2D at 0x20cd424e668>,
#  <matplotlib.lines.Line2D at 0x20cd424e7b8>,
#  <matplotlib.lines.Line2D at 0x20cd424e908>,
#  <matplotlib.lines.Line2D at 0x20cd424ea58>,
#  <matplotlib.lines.Line2D at 0x20cd424eba8>,
#  <matplotlib.lines.Line2D at 0x20cd424ecf8>,
#  <matplotlib.lines.Line2D at 0x20cd424ee48>,
#  <matplotlib.lines.Line2D at 0x20cd424ef98>,
#  <matplotlib.lines.Line2D at 0x20cd4253128>,
#  <matplotlib.lines.Line2D at 0x20cd4253278>,
#  <matplotlib.lines.Line2D at 0x20cd42533c8>,
#  <matplotlib.lines.Line2D at 0x20cd4253518>,
#  <matplotlib.lines.Line2D at 0x20cd4253668>,
#  <matplotlib.lines.Line2D at 0x20cd42537b8>,
#  <matplotlib.lines.Line2D at 0x20cd4253908>,
#  <matplotlib.lines.Line2D at 0x20cd4253a58>,
#  <matplotlib.lines.Line2D at 0x20cd4253ba8>,
#  <matplotlib.lines.Line2D at 0x20cd4253cf8>,
#  <matplotlib.lines.Line2D at 0x20cd4253e48>,
#  <matplotlib.lines.Line2D at 0x20cd4253f98>,
#  <matplotlib.lines.Line2D at 0x20cd4259128>,
#  <matplotlib.lines.Line2D at 0x20cd4259278>,
#  <matplotlib.lines.Line2D at 0x20cd42593c8>,
#  <matplotlib.lines.Line2D at 0x20cd4259518>,
#  <matplotlib.lines.Line2D at 0x20cd4259668>,
#  <matplotlib.lines.Line2D at 0x20cd42597b8>,
#  <matplotlib.lines.Line2D at 0x20cd4259908>,
#  <matplotlib.lines.Line2D at 0x20cd4259a58>,
#  <matplotlib.lines.Line2D at 0x20cd4259ba8>,
#  <matplotlib.lines.Line2D at 0x20cd4259cf8>,
#  <matplotlib.lines.Line2D at 0x20cd4259e48>,
#  <matplotlib.lines.Line2D at 0x20cd4259f98>,
#  <matplotlib.lines.Line2D at 0x20cd425d128>,
#  <matplotlib.lines.Line2D at 0x20cd425d278>,
#  <matplotlib.lines.Line2D at 0x20cd425d3c8>,
#  <matplotlib.lines.Line2D at 0x20cd425d518>,
#  <matplotlib.lines.Line2D at 0x20cd425d668>,
#  <matplotlib.lines.Line2D at 0x20cd425d7b8>,
#  <matplotlib.lines.Line2D at 0x20cd425d908>,
#  <matplotlib.lines.Line2D at 0x20cd425da58>,
#  <matplotlib.lines.Line2D at 0x20cd425dba8>,
#  <matplotlib.lines.Line2D at 0x20cd425dcf8>,
#  <matplotlib.lines.Line2D at 0x20cd425de48>,
#  <matplotlib.lines.Line2D at 0x20cd425df98>,
#  <matplotlib.lines.Line2D at 0x20cd4262128>,
#  <matplotlib.lines.Line2D at 0x20cd4262278>,
#  <matplotlib.lines.Line2D at 0x20cd42623c8>,
#  <matplotlib.lines.Line2D at 0x20cd4262518>,
#  <matplotlib.lines.Line2D at 0x20cd4262668>,
#  <matplotlib.lines.Line2D at 0x20cd42627b8>,
#  <matplotlib.lines.Line2D at 0x20cd4262908>,
#  <matplotlib.lines.Line2D at 0x20cd4262a58>]

# %%
plt.plot(iris[:50].T, 'r-', alpha=0.2)
plt.plot(iris[50:100].T, 'g-', alpha=0.2)
plt.plot(iris[100:].T, 'b-', alpha=0.2)
pass

# %% [markdown]
# ### 연습문제
# - Iris 데이터의 샘플별 평균과 표준편차 꺽은선 그래프를 최대한 이쁘게 그리시오.

# %%
iris = np.loadtxt('iris.csv', delimiter=',', skiprows=1, usecols=[0,1,2,3])

# %%
m = iris.mean(axis=1)
s = iris.std(axis=1)

# %%
plt.figure(figsize=[12,8])

plt.plot(m, 'g-', label='mean')
plt.plot(s, 'b-', label='std')

plt.legend()
plt.title('Iris (mean & std)', fontsize=30)
plt.xlabel('samples', fontsize=30)
plt.ylabel('values', fontsize=30)
plt.ylim(0,7)
plt.xticks(range(0,151,25), rotation=60)
plt.grid()
pass

# %%
a = np.array([[1,2,3],[10,11,12]])
plt.plot(a) # 열 단위로 그린다

plt.figure() # 전체 그림을 리셋한다
plt.plot(a.T)
# Out:
# [<matplotlib.lines.Line2D at 0xe7f6950>,
#  <matplotlib.lines.Line2D at 0xe7f6b70>]

# %% [markdown]
# ### scatter() 함수
# - 산점도 그림을 그린다.
# - 보통 속성이 2개인 샘플들의 위치를 점으로 찍는다.

# %%
a = np.array([[1,1], [2,3], [3,2]])
plt.scatter(a[:,0], a[:,1]) # 각각 X축과 Y축
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
f = open('iris.csv')

line = f.readline()
features = line.strip().split(',')[:4]

labels = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

data = []
for line in f:
    l = line.strip().split(',')
    l[:4] = [float(i) for i in l[:4]]
    l[4] = labels.index(l[4])
    
    data.append(l)

f.close()

iris = np.array(data)

# %%
plt.figure(figsize=[10,6])
plt.scatter(iris[:,0],iris[:,3], c=iris[:,-1], s=iris[:,2]*50, alpha=0.5,
           cmap='cool')
plt.axis('equal')
plt.colorbar()

# %%
wine = np.loadtxt('winequality-red.csv', delimiter=';', skiprows=1)
wine[:3]
# Out:
# array([[7.400e+00, 7.000e-01, 0.000e+00, 1.900e+00, 7.600e-02, 1.100e+01,
#         3.400e+01, 9.978e-01, 3.510e+00, 5.600e-01, 9.400e+00, 5.000e+00],
#        [7.800e+00, 8.800e-01, 0.000e+00, 2.600e+00, 9.800e-02, 2.500e+01,
#         6.700e+01, 9.968e-01, 3.200e+00, 6.800e-01, 9.800e+00, 5.000e+00],
#        [7.800e+00, 7.600e-01, 4.000e-02, 2.300e+00, 9.200e-02, 1.500e+01,
#         5.400e+01, 9.970e-01, 3.260e+00, 6.500e-01, 9.800e+00, 5.000e+00]])

# %%
plt.scatter(wine[:,-2], wine[:,-3], c=wine[:,-1], vmin=6, vmax=7, alpha=0.1,
           cmap='cool')
plt.colorbar()

# %% [markdown]
# - 색상맵 옵션을 cmap 이라고 한다. 아래 사이트를 확인하자.
# - https://matplotlib.org/examples/color/colormaps_reference.html

# %%
x = np.random.randn(1000)
y = 2*np.random.randn(1000)
plt.scatter(x,y, alpha=0.2)
plt.axis('equal')
# Out:
# (-3.2583246641737658, 3.1425582722371543, -6.79444683872001, 8.261452706787136)

# %%
x1 = np.random.normal(0,1,1000)
y1 = np.random.normal(0,1,1000)
#plt.scatter(x1,y1, color='red', alpha=0.1)

x2 = np.random.normal(5,3,1000)
y2 = np.random.normal(3,2,1000)


data1 = np.c_[x1, y1]
data2 = np.c_[x2, y2]

data = np.r_[data1, data2] # 2000X3
label = np.zeros(2000)
label[1000:]=1
data = np.c_[data, label]
data.shape
# Out:
# (2000, 3)

# %%
x = np.random.randn(500) # normal()
y = 2*x + 5 + np.random.randn(500) # normal(0, 0.1, 500)

plt.plot(x, 2*x+5, 'r:')
plt.scatter(x,y,alpha=0.1)
#plt.vlines([0],-5,5, linestyles=':')
#plt.hlines([0],-3,3, linestyles=':')
plt.axis('equal')
# Out:
# (-4.4105764610956335, 3.14549770381234, -3.78337971665793, 12.238165272555372)

# %%
x = np.random.normal(0,2,1000) # normal()
y = x**2 + 1 + np.random.randn(1000) # normal(0, 0.1, 500)
plt.scatter(x,y,alpha=0.1)
#plt.vlines([0],-5,5, linestyles=':')
#plt.hlines([0],-3,3, linestyles=':')
plt.axis('equal')
# Out:
# (-7.495124954170509, 8.849007659340408, -4.693527666695109, 68.8092030567429)

# %%
x = np.random.randn(100)
y = np.random.randn(100)
label = np.random.randint(2, size=100)
sz = np.random.rand(100)*100

plt.scatter(x, y, c=label, s=sz, cmap='winter')
plt.colorbar()

# %% [markdown]
# ### 한글 출력

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/uni_hsr.ttf").get_name()
# h2gprm.ttf, uni_hsr.ttf, hynaml.ttf, nanumgothic.ttf, ng.ttf(나눔고딕)
rc('font', family=font_name)

plt.plot([1,2,3,4], label='올라감')
plt.plot([4,3,2,1], label='내려감')
plt.text(1.5,3,'텍스트')

plt.title('직선 2개', fontsize=30)
plt.xlabel('X축')
plt.ylabel('Y축')
plt.legend()

# %%
import matplotlib.font_manager as fm

prop=fm.FontProperties(fname='C:/Windows/Fonts/gulim.ttc')

plt.title('헬로 플롯! (Hello, plot!)', fontproperties=prop, fontsize=20)
# fontproperties 뒤에 fontsize 가 나와야 함
plt.scatter(np.random.randn(100), np.random.randn(100), c=np.random.randn(100), s=50, alpha=0.5)
plt.xlabel('안녕하세요', fontproperties=prop)
plt.legend(['하나'], prop=prop)
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ### 막대 그래프
# - bar(), barh()

# %%
plt.bar(range(20), np.random.randint(10,size=20), color='#00ff00')
# Out:
# <Container object of 20 artists>

# %%
plt.barh(range(10), np.random.randint(10,size=10))
# Out:
# <Container object of 10 artists>

# %%
a = np.random.randint(10,size=10)
b = np.random.randint(10,size=10)

plt.bar(range(10), a, color='blue')
plt.bar(range(10), b, bottom=a, color='pink')
plt.legend(['Man', 'Woman'])

# %% [markdown]
# ### 히스토그램
# - 값들을 구간으로 나눠서 갯수를 막대그래프로 보여준다.

# %%
a = np.random.randn(10000)
display(a.max(), a.min())
plt.hist(a, bins=30, range=[-3,3])
# Out:
# 3.7820340843375804
# -3.572066143011756
# (array([ 12.,  16.,  38.,  57.,  69., 141., 176., 250., 335., 446., 538.,
#         625., 658., 768., 823., 814., 762., 727., 607., 533., 428., 353.,
#         265., 200., 106., 101.,  65.,  28.,  15.,  13.]),
#  array([-3. , -2.8, -2.6, -2.4, -2.2, -2. , -1.8, -1.6, -1.4, -1.2, -1. ,
#         -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,
#          1.4,  1.6,  1.8,  2. ,  2.2,  2.4,  2.6,  2.8,  3. ]),
#  <a list of 30 Patch objects>)

# %%
a = np.random.randint(100,size=10000)
plt.hist(a, bins=range(0,101,5))
plt.xticks(range(0,101,5), rotation=90)
plt.xlabel('값')
plt.ylabel('출현횟수')
print('')

# %%
a = np.random.randn(1000)
b = np.random.normal(10,5,size=1000)
_, bins = np.histogram(np.r_[a,b], 50)

# %%
plt.hist(a, bins=bins,alpha=0.3) # bins=bins, 
plt.hist(b, bins=bins,alpha=0.3)
plt.legend(['zero', 'one'])

# %%
iris = np.loadtxt('iris.csv', delimiter=',', skiprows=1, usecols=[0,1,2,3])

_, b = np.histogram(iris[:,2], bins=30)
b
# Out:
# array([1.        , 1.19666667, 1.39333333, 1.59      , 1.78666667,
#        1.98333333, 2.18      , 2.37666667, 2.57333333, 2.77      ,
#        2.96666667, 3.16333333, 3.36      , 3.55666667, 3.75333333,
#        3.95      , 4.14666667, 4.34333333, 4.54      , 4.73666667,
#        4.93333333, 5.13      , 5.32666667, 5.52333333, 5.72      ,
#        5.91666667, 6.11333333, 6.31      , 6.50666667, 6.70333333,
#        6.9       ])

# %%
#plt.hist(iris[:,0], bins=20)
plt.hist(iris[:,2][:50], bins=b, alpha=0.5) # setosa
plt.hist(iris[:,2][50:100], bins=b, alpha=0.5) # versicolor
plt.hist(iris[:,2][100:], bins=b, alpha=0.5) # virginica
plt.legend(['setosa', 'versicolor', 'virginica'])
pass

# %%
plt.hist2d(np.random.normal(3,2,size=1000), np.random.normal(5,3,size=1000),
           bins=20, cmap='gray')
plt.axis('equal')
# Out:
# (-2.8268879732469863,
#  10.047624236679873,
#  -3.5114078974397316,
#  13.785691608376956)

# %%
plt.hexbin(np.random.normal(3,2,size=1000), np.random.normal(5,3,size=1000),
           gridsize=10, cmap='gray')
plt.axis('equal')
# Out:
# (-4.153072584125245, 8.585520362298652, -4.402258269809241, 14.442239148476467)

# %% [markdown]
# ### 박스 플롯

# %%
n=1
if n==0:
    pass
else:
    print(n)
# Out:
# 2
# 5

# %%
a = np.array([99,-99])
b1, _ = a
b1
# Out:
# 99

# %%
a = np.zeros([100,3])
a[:,0] = np.random.randn(100)
a[:,1] = np.random.normal(5,2,size=100)
a[:,2] = np.random.normal(10,5,size=100)

plt.boxplot(a)
pass

# %%
plt.boxplot(iris)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2386cb3a828>,
#   <matplotlib.lines.Line2D at 0x2386cb3ac50>,
#   <matplotlib.lines.Line2D at 0x2386cb2a5c0>,
#   <matplotlib.lines.Line2D at 0x2386cb2a9e8>,
#   <matplotlib.lines.Line2D at 0x2386cb2efd0>,
#   <matplotlib.lines.Line2D at 0x2386c7d3a58>,
#   <matplotlib.lines.Line2D at 0x2386c7b2d68>,
#   <matplotlib.lines.Line2D at 0x2386c7b6518>,
#   <matplotlib.lines.Line2D at 0x2386c7cae48>,
#   <matplotlib.lines.Line2D at 0x2386c7caf28>],
#  'caps': [<matplotlib.lines.Line2D at 0x2386cb3ad30>,
#   <matplotlib.lines.Line2D at 0x2386cb324e0>,
#   <matplotlib.lines.Line2D at 0x2386cb2ae10>,
#   <matplotlib.lines.Line2D at 0x2386cb2aef0>,
#   <matplotlib.lines.Line2D at 0x2386c7d3518>,
#   <matplotlib.lines.Line2D at 0x2386c7d3400>,
#   <matplotlib.lines.Line2D at 0x2386c7b6940>,
#   <matplotlib.lines.Line2D at 0x2386c7b6d68>,
#   <matplotlib.lines.Line2D at 0x2386c7cb6d8>,
#   <matplotlib.lines.Line2D at 0x2386c7cbb00>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2386cb3a2b0>,
#   <matplotlib.lines.Line2D at 0x2386cb32dd8>,
#   <matplotlib.lines.Line2D at 0x2386cb2eef0>,
#   <matplotlib.lines.Line2D at 0x2386c7b2c88>,
#   <matplotlib.lines.Line2D at 0x2386c7caa20>],
#  'medians': [<matplotlib.lines.Line2D at 0x2386cb32908>,
#   <matplotlib.lines.Line2D at 0x2386cb2e6a0>,
#   <matplotlib.lines.Line2D at 0x2386c7b2438>,
#   <matplotlib.lines.Line2D at 0x2386c7b6e48>,
#   <matplotlib.lines.Line2D at 0x2386c7cbf28>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2386cb32d30>,
#   <matplotlib.lines.Line2D at 0x2386cb2eac8>,
#   <matplotlib.lines.Line2D at 0x2386c7b2860>,
#   <matplotlib.lines.Line2D at 0x2386c7ca5f8>,
#   <matplotlib.lines.Line2D at 0x2386cadf390>],
#  'means': []}

# %% [markdown]
# ### imshow()
# - 2차원 형태의 데이터가 있을 때, 2차원 좌표상에서 그림을 그린다.
# - 이미지 출력에도 사용된다.

# %%
a = np.random.randn(64,64)
plt.imshow(a)
plt.colorbar(shrink=0.7)

# %%
a = np.random.randn(64,64)
plt.imshow(a, interpolation='none', cmap='gray_r')
plt.colorbar(shrink=0.7)

# %%
a = np.random.randn(64,64)
plt.imshow(a, interpolation='none', vmin=-1, vmax=1, cmap='gray_r')
plt.colorbar(shrink=0.7)

# %%
a = np.random.randn(64,64)
plt.imshow(a, interpolation='none', cmap='gray_r')
plt.colorbar(shrink=0.7)

# %%
a = [ [x**2 + y**2 for x in range(3)] for y in range(3)]
np.array(a)
# Out:
# array([[0, 1, 4],
#        [1, 2, 5],
#        [4, 5, 8]])

# %%
x = np.arange(100)
y = np.arange(100)

data = []
for _x in x:
    k= []
    for _y in y:
        k.append((_x-30)**2 + (_y-10)**2)
    data.append(k)
    
plt.imshow(data, cmap='gray_r')

# %%
a = [[(x-30)**2 + (y-10)**2 for x in range(100)] for y in range(100)]
a
# Out:
# [[1000,
#   941,
#   884,
#   829,
#   776,
#   725,
#   676,
#   629,
#   584,
#   541,
#   500,
#   461,
#   424,
#   389,
#   356,
#   325,
#   296,
#   269,
#   244,
#   221,
#   200,
#   181,
#   164,
#   149,
#   136,
#   125,
#   116,
#   109,
#   104,
#   101,
#   100,
#   101,
#   104,
#   109,
#   116,
#   125,
#   136,
#   149,
#   164,
#   181,
#   200,
#   221,
#   244,
#   269,
#   296,
#   325,
#   356,
#   389,
#   424,
#   461,
#   500,
#   541,
#   584,
#   629,
#   676,
#   725,
#   776,
#   829,
#   884,
#   941,
#   1000,
#   1061,
#   1124,
#   1189,
#   1256,
#   1325,
#   1396,
#   1469,
#   1544,
#   1621,
#   1700,
#   1781,
#   1864,
#   1949,
#   2036,
#   2125,
#   2216,
#   2309,
#   2404,
#   2501,
#   2600,
#   2701,
#   2804,
#   2909,
#   3016,
#   3125,
#   3236,
#   3349,
#   3464,
#   3581,
#   3700,
#   3821,
#   3944,
#   4069,
#   4196,
#   4325,
#   4456,
#   4589,
#   4724,
#   4861],
#  [981,
#   922,
#   865,
#   810,
#   757,
#   706,
#   657,
#   610,
#   565,
#   522,
#   481,
#   442,
#   405,
#   370,
#   337,
#   306,
#   277,
#   250,
#   225,
#   202,
#   181,
#   162,
#   145,
#   130,
#   117,
#   106,
#   97,
#   90,
#   85,
#   82,
#   81,
#   82,
#   85,
#   90,
#   97,
#   106,
#   117,
#   130,
#   145,
#   162,
#   181,
#   202,
#   225,
#   250,
#   277,
#   306,
#   337,
#   370,
#   405,
#   442,
#   481,
#   522,
#   565,
#   610,
#   657,
#   706,
#   757,
#   810,
#   865,
#   922,
#   981,
#   1042,
#   1105,
#   1170,
#   1237,
#   1306,
#   1377,
#   1450,
#   1525,
#   1602,
#   1681,
#   1762,
#   1845,
#   1930,
#   2017,
#   2106,
#   2197,
#   2290,
#   2385,
#   2482,
#   2581,
#   2682,
#   2785,
#   2890,
#   2997,
#   3106,
#   3217,
#   3330,
#   3445,
#   3562,
#   3681,
#   3802,
#   3925,
#   4050,
#   4177,
#   4306,
#   4437,
#   4570,
#   4705,
#   4842],
#  [964,
#   905,
#   848,
#   793,
#   740,
#   689,
#   640,
#   593,
#   548,
#   505,
#   464,
#   425,
#   388,
#   353,
#   320,
#   289,
#   260,
#   233,
#   208,
#   185,
#   164,
#   145,
#   128,
#   113,
#   100,
#   89,
#   80,
#   73,
#   68,
#   65,
#   64,
#   65,
#   68,
#   73,
#   80,
#   89,
#   100,
#   113,
#   128,
#   145,
#   164,
#   185,
#   208,
#   233,
#   260,
#   289,
#   320,
#   353,
#   388,
#   425,
#   464,
#   505,
#   548,
#   593,
#   640,
#   689,
#   740,
#   793,
#   848,
#   905,
#   964,
#   1025,
#   1088,
#   1153,
#   1220,
#   1289,
#   1360,
#   1433,
#   1508,
#   1585,
#   1664,
#   1745,
#   1828,
#   1913,
#   2000,
#   2089,
#   2180,
#   2273,
#   2368,
#   2465,
#   2564,
#   2665,
#   2768,
#   2873,
#   2980,
#   3089,
#   3200,
#   3313,
#   3428,
#   3545,
#   3664,
#   3785,
#   3908,
#   4033,
#   4160,
#   4289,
#   4420,
#   4553,
#   4688,
#   4825],
#  [949,
#   890,
#   833,
#   778,
#   725,
#   674,
#   625,
#   578,
#   533,
#   490,
#   449,
#   410,
#   373,
#   338,
#   305,
#   274,
#   245,
#   218,
#   193,
#   170,
#   149,
#   130,
#   113,
#   98,
#   85,
#   74,
#   65,
#   58,
#   53,
#   50,
#   49,
#   50,
#   53,
#   58,
#   65,
#   74,
#   85,
#   98,
#   113,
#   130,
#   149,
#   170,
#   193,
#   218,
#   245,
#   274,
#   305,
#   338,
#   373,
#   410,
#   449,
#   490,
#   533,
#   578,
#   625,
#   674,
#   725,
#   778,
#   833,
#   890,
#   949,
#   1010,
#   1073,
#   1138,
#   1205,
#   1274,
#   1345,
#   1418,
#   1493,
#   1570,
#   1649,
#   1730,
#   1813,
#   1898,
#   1985,
#   2074,
#   2165,
#   2258,
#   2353,
#   2450,
#   2549,
#   2650,
#   2753,
#   2858,
#   2965,
#   3074,
#   3185,
#   3298,
#   3413,
#   3530,
#   3649,
#   3770,
#   3893,
#   4018,
#   4145,
#   4274,
#   4405,
#   4538,
#   4673,
#   4810],
#  [936,
#   877,
#   820,
#   765,
#   712,
#   661,
#   612,
#   565,
#   520,
#   477,
#   436,
#   397,
#   360,
#   325,
#   292,
#   261,
#   232,
#   205,
#   180,
#   157,
#   136,
#   117,
#   100,
#   85,
#   72,
#   61,
#   52,
#   45,
#   40,
#   37,
#   36,
#   37,
#   40,
#   45,
#   52,
#   61,
#   72,
#   85,
#   100,
#   117,
#   136,
#   157,
#   180,
#   205,
#   232,
#   261,
#   292,
#   325,
#   360,
#   397,
#   436,
#   477,
#   520,
#   565,
#   612,
#   661,
#   712,
#   765,
#   820,
#   877,
#   936,
#   997,
#   1060,
#   1125,
#   1192,
#   1261,
#   1332,
#   1405,
#   1480,
#   1557,
#   1636,
#   1717,
#   1800,
#   1885,
#   1972,
#   2061,
#   2152,
#   2245,
#   2340,
#   2437,
#   2536,
#   2637,
#   2740,
#   2845,
#   2952,
#   3061,
#   3172,
#   3285,
#   3400,
#   3517,
#   3636,
#   3757,
#   3880,
#   4005,
#   4132,
#   4261,
#   4392,
#   4525,
#   4660,
#   4797],
#  [925,
#   866,
#   809,
#   754,
#   701,
#   650,
#   601,
#   554,
#   509,
#   466,
#   425,
#   386,
#   349,
#   314,
#   281,
#   250,
#   221,
#   194,
#   169,
#   146,
#   125,
#   106,
#   89,
#   74,
#   61,
#   50,
#   41,
#   34,
#   29,
#   26,
#   25,
#   26,
#   29,
#   34,
#   41,
#   50,
#   61,
#   74,
#   89,
#   106,
#   125,
#   146,
#   169,
#   194,
#   221,
#   250,
#   281,
#   314,
#   349,
#   386,
#   425,
#   466,
#   509,
#   554,
#   601,
#   650,
#   701,
#   754,
#   809,
#   866,
#   925,
#   986,
#   1049,
#   1114,
#   1181,
#   1250,
#   1321,
#   1394,
#   1469,
#   1546,
#   1625,
#   1706,
#   1789,
#   1874,
#   1961,
#   2050,
#   2141,
#   2234,
#   2329,
#   2426,
#   2525,
#   2626,
#   2729,
#   2834,
#   2941,
#   3050,
#   3161,
#   3274,
#   3389,
#   3506,
#   3625,
#   3746,
#   3869,
#   3994,
#   4121,
#   4250,
#   4381,
#   4514,
#   4649,
#   4786],
#  [916,
#   857,
#   800,
#   745,
#   692,
#   641,
#   592,
#   545,
#   500,
#   457,
#   416,
#   377,
#   340,
#   305,
#   272,
#   241,
#   212,
#   185,
#   160,
#   137,
#   116,
#   97,
#   80,
#   65,
#   52,
#   41,
#   32,
#   25,
#   20,
#   17,
#   16,
#   17,
#   20,
#   25,
#   32,
#   41,
#   52,
#   65,
#   80,
#   97,
#   116,
#   137,
#   160,
#   185,
#   212,
#   241,
#   272,
#   305,
#   340,
#   377,
#   416,
#   457,
#   500,
#   545,
#   592,
#   641,
#   692,
#   745,
#   800,
#   857,
#   916,
#   977,
#   1040,
#   1105,
#   1172,
#   1241,
#   1312,
#   1385,
#   1460,
#   1537,
#   1616,
#   1697,
#   1780,
#   1865,
#   1952,
#   2041,
#   2132,
#   2225,
#   2320,
#   2417,
#   2516,
#   2617,
#   2720,
#   2825,
#   2932,
#   3041,
#   3152,
#   3265,
#   3380,
#   3497,
#   3616,
#   3737,
#   3860,
#   3985,
#   4112,
#   4241,
#   4372,
#   4505,
#   4640,
#   4777],
#  [909,
#   850,
#   793,
#   738,
#   685,
#   634,
#   585,
#   538,
#   493,
#   450,
#   409,
#   370,
#   333,
#   298,
#   265,
#   234,
#   205,
#   178,
#   153,
#   130,
#   109,
#   90,
#   73,
#   58,
#   45,
#   34,
#   25,
#   18,
#   13,
#   10,
#   9,
#   10,
#   13,
#   18,
#   25,
#   34,
#   45,
#   58,
#   73,
#   90,
#   109,
#   130,
#   153,
#   178,
#   205,
#   234,
#   265,
#   298,
#   333,
#   370,
#   409,
#   450,
#   493,
#   538,
#   585,
#   634,
#   685,
#   738,
#   793,
#   850,
#   909,
#   970,
#   1033,
#   1098,
#   1165,
#   1234,
#   1305,
#   1378,
#   1453,
#   1530,
#   1609,
#   1690,
#   1773,
#   1858,
#   1945,
#   2034,
#   2125,
#   2218,
#   2313,
#   2410,
#   2509,
#   2610,
#   2713,
#   2818,
#   2925,
#   3034,
#   3145,
#   3258,
#   3373,
#   3490,
#   3609,
#   3730,
#   3853,
#   3978,
#   4105,
#   4234,
#   4365,
#   4498,
#   4633,
#   4770],
#  [904,
#   845,
#   788,
#   733,
#   680,
#   629,
#   580,
#   533,
#   488,
#   445,
#   404,
#   365,
#   328,
#   293,
#   260,
#   229,
#   200,
#   173,
#   148,
#   125,
#   104,
#   85,
#   68,
#   53,
#   40,
#   29,
#   20,
#   13,
#   8,
#   5,
#   4,
#   5,
#   8,
#   13,
#   20,
#   29,
#   40,
#   53,
#   68,
#   85,
#   104,
#   125,
#   148,
#   173,
#   200,
#   229,
#   260,
#   293,
#   328,
#   365,
#   404,
#   445,
#   488,
#   533,
#   580,
#   629,
#   680,
#   733,
#   788,
#   845,
#   904,
#   965,
#   1028,
#   1093,
#   1160,
#   1229,
#   1300,
#   1373,
#   1448,
#   1525,
#   1604,
#   1685,
#   1768,
#   1853,
#   1940,
#   2029,
#   2120,
#   2213,
#   2308,
#   2405,
#   2504,
#   2605,
#   2708,
#   2813,
#   2920,
#   3029,
#   3140,
#   3253,
#   3368,
#   3485,
#   3604,
#   3725,
#   3848,
#   3973,
#   4100,
#   4229,
#   4360,
#   4493,
#   4628,
#   4765],
#  [901,
#   842,
#   785,
#   730,
#   677,
#   626,
#   577,
#   530,
#   485,
#   442,
#   401,
#   362,
#   325,
#   290,
#   257,
#   226,
#   197,
#   170,
#   145,
#   122,
#   101,
#   82,
#   65,
#   50,
#   37,
#   26,
#   17,
#   10,
#   5,
#   2,
#   1,
#   2,
#   5,
#   10,
#   17,
#   26,
#   37,
#   50,
#   65,
#   82,
#   101,
#   122,
#   145,
#   170,
#   197,
#   226,
#   257,
#   290,
#   325,
#   362,
#   401,
#   442,
#   485,
#   530,
#   577,
#   626,
#   677,
#   730,
#   785,
#   842,
#   901,
#   962,
#   1025,
#   1090,
#   1157,
#   1226,
#   1297,
#   1370,
#   1445,
#   1522,
#   1601,
#   1682,
#   1765,
#   1850,
#   1937,
#   2026,
#   2117,
#   2210,
#   2305,
#   2402,
#   2501,
#   2602,
#   2705,
#   2810,
#   2917,
#   3026,
#   3137,
#   3250,
#   3365,
#   3482,
#   3601,
#   3722,
#   3845,
#   3970,
#   4097,
#   4226,
#   4357,
#   4490,
#   4625,
#   4762],
#  [900,
#   841,
#   784,
#   729,
#   676,
#   625,
#   576,
#   529,
#   484,
#   441,
#   400,
#   361,
#   324,
#   289,
#   256,
#   225,
#   196,
#   169,
#   144,
#   121,
#   100,
#   81,
#   64,
#   49,
#   36,
#   25,
#   16,
#   9,
#   4,
#   1,
#   0,
#   1,
#   4,
#   9,
#   16,
#   25,
#   36,
#   49,
#   64,
#   81,
#   100,
#   121,
#   144,
#   169,
#   196,
#   225,
#   256,
#   289,
#   324,
#   361,
#   400,
#   441,
#   484,
#   529,
#   576,
#   625,
#   676,
#   729,
#   784,
#   841,
#   900,
#   961,
#   1024,
#   1089,
#   1156,
#   1225,
#   1296,
#   1369,
#   1444,
#   1521,
#   1600,
#   1681,
#   1764,
#   1849,
#   1936,
#   2025,
#   2116,
#   2209,
#   2304,
#   2401,
#   2500,
#   2601,
#   2704,
#   2809,
#   2916,
#   3025,
#   3136,
#   3249,
#   3364,
#   3481,
#   3600,
#   3721,
#   3844,
#   3969,
#   4096,
#   4225,
#   4356,
#   4489,
#   4624,
#   4761],
#  [901,
#   842,
#   785,
#   730,
#   677,
#   626,
#   577,
#   530,
#   485,
#   442,
#   401,
#   362,
#   325,
#   290,
#   257,
#   226,
#   197,
#   170,
#   145,
#   122,
#   101,
#   82,
#   65,
#   50,
#   37,
#   26,
#   17,
#   10,
#   5,
#   2,
#   1,
#   2,
#   5,
#   10,
#   17,
#   26,
#   37,
#   50,
#   65,
#   82,
#   101,
#   122,
#   145,
#   170,
#   197,
#   226,
#   257,
#   290,
#   325,
#   362,
#   401,
#   442,
#   485,
#   530,
#   577,
#   626,
#   677,
#   730,
#   785,
#   842,
#   901,
#   962,
#   1025,
#   1090,
#   1157,
#   1226,
#   1297,
#   1370,
#   1445,
#   1522,
#   1601,
#   1682,
#   1765,
#   1850,
#   1937,
#   2026,
#   2117,
#   2210,
#   2305,
#   2402,
#   2501,
#   2602,
#   2705,
#   2810,
#   2917,
#   3026,
#   3137,
#   3250,
#   3365,
#   3482,
#   3601,
#   3722,
#   3845,
#   3970,
#   4097,
#   4226,
#   4357,
#   4490,
#   4625,
#   4762],
#  [904,
#   845,
#   788,
#   733,
#   680,
#   629,
#   580,
#   533,
#   488,
#   445,
#   404,
#   365,
#   328,
#   293,
#   260,
#   229,
#   200,
#   173,
#   148,
#   125,
#   104,
#   85,
#   68,
#   53,
#   40,
#   29,
#   20,
#   13,
#   8,
#   5,
#   4,
#   5,
#   8,
#   13,
#   20,
#   29,
#   40,
#   53,
#   68,
#   85,
#   104,
#   125,
#   148,
#   173,
#   200,
#   229,
#   260,
#   293,
#   328,
#   365,
#   404,
#   445,
#   488,
#   533,
#   580,
#   629,
#   680,
#   733,
#   788,
#   845,
#   904,
#   965,
#   1028,
#   1093,
#   1160,
#   1229,
#   1300,
#   1373,
#   1448,
#   1525,
#   1604,
#   1685,
#   1768,
#   1853,
#   1940,
#   2029,
#   2120,
#   2213,
#   2308,
#   2405,
#   2504,
#   2605,
#   2708,
#   2813,
#   2920,
#   3029,
#   3140,
#   3253,
#   3368,
#   3485,
#   3604,
#   3725,
#   3848,
#   3973,
#   4100,
#   4229,
#   4360,
#   4493,
#   4628,
#   4765],
#  [909,
#   850,
#   793,
#   738,
#   685,
#   634,
#   585,
#   538,
#   493,
#   450,
#   409,
#   370,
#   333,
#   298,
#   265,
#   234,
#   205,
#   178,
#   153,
#   130,
#   109,
#   90,
#   73,
#   58,
#   45,
#   34,
#   25,
#   18,
#   13,
#   10,
#   9,
#   10,
#   13,
#   18,
#   25,
#   34,
#   45,
#   58,
#   73,
#   90,
#   109,
#   130,
#   153,
#   178,
#   205,
#   234,
#   265,
#   298,
#   333,
#   370,
#   409,
#   450,
#   493,
#   538,
#   585,
#   634,
#   685,
#   738,
#   793,
#   850,
#   909,
#   970,
#   1033,
#   1098,
#   1165,
#   1234,
#   1305,
#   1378,
#   1453,
#   1530,
#   1609,
#   1690,
#   1773,
#   1858,
#   1945,
#   2034,
#   2125,
#   2218,
#   2313,
#   2410,
#   2509,
#   2610,
#   2713,
#   2818,
#   2925,
#   3034,
#   3145,
#   3258,
#   3373,
#   3490,
#   3609,
#   3730,
#   3853,
#   3978,
#   4105,
#   4234,
#   4365,
#   4498,
#   4633,
#   4770],
#  [916,
#   857,
#   800,
#   745,
#   692,
#   641,
#   592,
#   545,
#   500,
#   457,
#   416,
#   377,
#   340,
#   305,
#   272,
#   241,
#   212,
#   185,
#   160,
#   137,
#   116,
#   97,
#   80,
#   65,
#   52,
#   41,
#   32,
#   25,
#   20,
#   17,
#   16,
#   17,
#   20,
#   25,
#   32,
#   41,
#   52,
#   65,
#   80,
#   97,
#   116,
#   137,
#   160,
#   185,
#   212,
#   241,
#   272,
#   305,
#   340,
#   377,
#   416,
#   457,
#   500,
#   545,
#   592,
#   641,
#   692,
#   745,
#   800,
#   857,
#   916,
#   977,
#   1040,
#   1105,
#   1172,
#   1241,
#   1312,
#   1385,
#   1460,
#   1537,
#   1616,
#   1697,
#   1780,
#   1865,
#   1952,
#   2041,
#   2132,
#   2225,
#   2320,
#   2417,
#   2516,
#   2617,
#   2720,
#   2825,
#   2932,
#   3041,
#   3152,
#   3265,
#   3380,
#   3497,
#   3616,
#   3737,
#   3860,
#   3985,
#   4112,
#   4241,
#   4372,
#   4505,
#   4640,
#   4777],
#  [925,
#   866,
#   809,
#   754,
#   701,
#   650,
#   601,
#   554,
#   509,
#   466,
#   425,
#   386,
#   349,
#   314,
#   281,
#   250,
#   221,
#   194,
#   169,
#   146,
#   125,
#   106,
#   89,
#   74,
#   61,
#   50,
#   41,
#   34,
#   29,
#   26,
#   25,
#   26,
#   29,
#   34,
#   41,
#   50,
#   61,
#   74,
#   89,
#   106,
#   125,
#   146,
#   169,
#   194,
#   221,
#   250,
#   281,
#   314,
#   349,
#   386,
#   425,
#   466,
#   509,
#   554,
#   601,
#   650,
#   701,
#   754,
#   809,
#   866,
#   925,
#   986,
#   1049,
#   1114,
#   1181,
#   1250,
#   1321,
#   1394,
#   1469,
#   1546,
#   1625,
#   1706,
#   1789,
#   1874,
#   1961,
#   2050,
#   2141,
#   2234,
#   2329,
#   2426,
#   2525,
#   2626,
#   2729,
#   2834,
#   2941,
#   3050,
#   3161,
#   3274,
#   3389,
#   3506,
#   3625,
#   3746,
#   3869,
#   3994,
#   4121,
#   4250,
#   4381,
#   4514,
#   4649,
#   4786],
#  [936,
#   877,
#   820,
#   765,
#   712,
#   661,
#   612,
#   565,
#   520,
#   477,
#   436,
#   397,
#   360,
#   325,
#   292,
#   261,
#   232,
#   205,
#   180,
#   157,
#   136,
#   117,
#   100,
#   85,
#   72,
#   61,
#   52,
#   45,
#   40,
#   37,
#   36,
#   37,
#   40,
#   45,
#   52,
#   61,
#   72,
#   85,
#   100,
#   117,
#   136,
#   157,
#   180,
#   205,
#   232,
#   261,
#   292,
#   325,
#   360,
#   397,
#   436,
#   477,
#   520,
#   565,
#   612,
#   661,
#   712,
#   765,
#   820,
#   877,
#   936,
#   997,
#   1060,
#   1125,
#   1192,
#   1261,
#   1332,
#   1405,
#   1480,
#   1557,
#   1636,
#   1717,
#   1800,
#   1885,
#   1972,
#   2061,
#   2152,
#   2245,
#   2340,
#   2437,
#   2536,
#   2637,
#   2740,
#   2845,
#   2952,
#   3061,
#   3172,
#   3285,
#   3400,
#   3517,
#   3636,
#   3757,
#   3880,
#   4005,
#   4132,
#   4261,
#   4392,
#   4525,
#   4660,
#   4797],
#  [949,
#   890,
#   833,
#   778,
#   725,
#   674,
#   625,
#   578,
#   533,
#   490,
#   449,
#   410,
#   373,
#   338,
#   305,
#   274,
#   245,
#   218,
#   193,
#   170,
#   149,
#   130,
#   113,
#   98,
#   85,
#   74,
#   65,
#   58,
#   53,
#   50,
#   49,
#   50,
#   53,
#   58,
#   65,
#   74,
#   85,
#   98,
#   113,
#   130,
#   149,
#   170,
#   193,
#   218,
#   245,
#   274,
#   305,
#   338,
#   373,
#   410,
#   449,
#   490,
#   533,
#   578,
#   625,
#   674,
#   725,
#   778,
#   833,
#   890,
#   949,
#   1010,
#   1073,
#   1138,
#   1205,
#   1274,
#   1345,
#   1418,
#   1493,
#   1570,
#   1649,
#   1730,
#   1813,
#   1898,
#   1985,
#   2074,
#   2165,
#   2258,
#   2353,
#   2450,
#   2549,
#   2650,
#   2753,
#   2858,
#   2965,
#   3074,
#   3185,
#   3298,
#   3413,
#   3530,
#   3649,
#   3770,
#   3893,
#   4018,
#   4145,
#   4274,
#   4405,
#   4538,
#   4673,
#   4810],
#  [964,
#   905,
#   848,
#   793,
#   740,
#   689,
#   640,
#   593,
#   548,
#   505,
#   464,
#   425,
#   388,
#   353,
#   320,
#   289,
#   260,
#   233,
#   208,
#   185,
#   164,
#   145,
#   128,
#   113,
#   100,
#   89,
#   80,
#   73,
#   68,
#   65,
#   64,
#   65,
#   68,
#   73,
#   80,
#   89,
#   100,
#   113,
#   128,
#   145,
#   164,
#   185,
#   208,
#   233,
#   260,
#   289,
#   320,
#   353,
#   388,
#   425,
#   464,
#   505,
#   548,
#   593,
#   640,
#   689,
#   740,
#   793,
#   848,
#   905,
#   964,
#   1025,
#   1088,
#   1153,
#   1220,
#   1289,
#   1360,
#   1433,
#   1508,
#   1585,
#   1664,
#   1745,
#   1828,
#   1913,
#   2000,
#   2089,
#   2180,
#   2273,
#   2368,
#   2465,
#   2564,
#   2665,
#   2768,
#   2873,
#   2980,
#   3089,
#   3200,
#   3313,
#   3428,
#   3545,
#   3664,
#   3785,
#   3908,
#   4033,
#   4160,
#   4289,
#   4420,
#   4553,
#   4688,
#   4825],
#  [981,
#   922,
#   865,
#   810,
#   757,
#   706,
#   657,
#   610,
#   565,
#   522,
#   481,
#   442,
#   405,
#   370,
#   337,
#   306,
#   277,
#   250,
#   225,
#   202,
#   181,
#   162,
#   145,
#   130,
#   117,
#   106,
#   97,
#   90,
#   85,
#   82,
#   81,
#   82,
#   85,
#   90,
#   97,
#   106,
#   117,
#   130,
#   145,
#   162,
#   181,
#   202,
#   225,
#   250,
#   277,
#   306,
#   337,
#   370,
#   405,
#   442,
#   481,
#   522,
#   565,
#   610,
#   657,
#   706,
#   757,
#   810,
#   865,
#   922,
#   981,
#   1042,
#   1105,
#   1170,
#   1237,
#   1306,
#   1377,
#   1450,
#   1525,
#   1602,
#   1681,
#   1762,
#   1845,
#   1930,
#   2017,
#   2106,
#   2197,
#   2290,
#   2385,
#   2482,
#   2581,
#   2682,
#   2785,
#   2890,
#   2997,
#   3106,
#   3217,
#   3330,
#   3445,
#   3562,
#   3681,
#   3802,
#   3925,
#   4050,
#   4177,
#   4306,
#   4437,
#   4570,
#   4705,
#   4842],
#  [1000,
#   941,
#   884,
#   829,
#   776,
#   725,
#   676,
#   629,
#   584,
#   541,
#   500,
#   461,
#   424,
#   389,
#   356,
#   325,
#   296,
#   269,
#   244,
#   221,
#   200,
#   181,
#   164,
#   149,
#   136,
#   125,
#   116,
#   109,
#   104,
#   101,
#   100,
#   101,
#   104,
#   109,
#   116,
#   125,
#   136,
#   149,
#   164,
#   181,
#   200,
#   221,
#   244,
#   269,
#   296,
#   325,
#   356,
#   389,
#   424,
#   461,
#   500,
#   541,
#   584,
#   629,
#   676,
#   725,
#   776,
#   829,
#   884,
#   941,
#   1000,
#   1061,
#   1124,
#   1189,
#   1256,
#   1325,
#   1396,
#   1469,
#   1544,
#   1621,
#   1700,
#   1781,
#   1864,
#   1949,
#   2036,
#   2125,
#   2216,
#   2309,
#   2404,
#   2501,
#   2600,
#   2701,
#   2804,
#   2909,
#   3016,
#   3125,
#   3236,
#   3349,
#   3464,
#   3581,
#   3700,
#   3821,
#   3944,
#   4069,
#   4196,
#   4325,
#   4456,
#   4589,
#   4724,
#   4861],
#  [1021,
#   962,
#   905,
#   850,
#   797,
#   746,
#   697,
#   650,
#   605,
#   562,
#   521,
#   482,
#   445,
#   410,
#   377,
#   346,
#   317,
#   290,
#   265,
#   242,
#   221,
#   202,
#   185,
#   170,
#   157,
#   146,
#   137,
#   130,
#   125,
#   122,
#   121,
#   122,
#   125,
#   130,
#   137,
#   146,
#   157,
#   170,
#   185,
#   202,
#   221,
#   242,
#   265,
#   290,
#   317,
#   346,
#   377,
#   410,
#   445,
#   482,
#   521,
#   562,
#   605,
#   650,
#   697,
#   746,
#   797,
#   850,
#   905,
#   962,
#   1021,
#   1082,
#   1145,
#   1210,
#   1277,
#   1346,
#   1417,
#   1490,
#   1565,
#   1642,
#   1721,
#   1802,
#   1885,
#   1970,
#   2057,
#   2146,
#   2237,
#   2330,
#   2425,
#   2522,
#   2621,
#   2722,
#   2825,
#   2930,
#   3037,
#   3146,
#   3257,
#   3370,
#   3485,
#   3602,
#   3721,
#   3842,
#   3965,
#   4090,
#   4217,
#   4346,
#   4477,
#   4610,
#   4745,
#   4882],
#  [1044,
#   985,
#   928,
#   873,
#   820,
#   769,
#   720,
#   673,
#   628,
#   585,
#   544,
#   505,
#   468,
#   433,
#   400,
#   369,
#   340,
#   313,
#   288,
#   265,
#   244,
#   225,
#   208,
#   193,
#   180,
#   169,
#   160,
#   153,
#   148,
#   145,
#   144,
#   145,
#   148,
#   153,
#   160,
#   169,
#   180,
#   193,
#   208,
#   225,
#   244,
#   265,
#   288,
#   313,
#   340,
#   369,
#   400,
#   433,
#   468,
#   505,
#   544,
#   585,
#   628,
#   673,
#   720,
#   769,
#   820,
#   873,
#   928,
#   985,
#   1044,
#   1105,
#   1168,
#   1233,
#   1300,
#   1369,
#   1440,
#   1513,
#   1588,
#   1665,
#   1744,
#   1825,
#   1908,
#   1993,
#   2080,
#   2169,
#   2260,
#   2353,
#   2448,
#   2545,
#   2644,
#   2745,
#   2848,
#   2953,
#   3060,
#   3169,
#   3280,
#   3393,
#   3508,
#   3625,
#   3744,
#   3865,
#   3988,
#   4113,
#   4240,
#   4369,
#   4500,
#   4633,
#   4768,
#   4905],
#  [1069,
#   1010,
#   953,
#   898,
#   845,
#   794,
#   745,
#   698,
#   653,
#   610,
#   569,
#   530,
#   493,
#   458,
#   425,
#   394,
#   365,
#   338,
#   313,
#   290,
#   269,
#   250,
#   233,
#   218,
#   205,
#   194,
#   185,
#   178,
#   173,
#   170,
#   169,
#   170,
#   173,
#   178,
#   185,
#   194,
#   205,
#   218,
#   233,
#   250,
#   269,
#   290,
#   313,
#   338,
#   365,
#   394,
#   425,
#   458,
#   493,
#   530,
#   569,
#   610,
#   653,
#   698,
#   745,
#   794,
#   845,
#   898,
#   953,
#   1010,
#   1069,
#   1130,
#   1193,
#   1258,
#   1325,
#   1394,
#   1465,
#   1538,
#   1613,
#   1690,
#   1769,
#   1850,
#   1933,
#   2018,
#   2105,
#   2194,
#   2285,
#   2378,
#   2473,
#   2570,
#   2669,
#   2770,
#   2873,
#   2978,
#   3085,
#   3194,
#   3305,
#   3418,
#   3533,
#   3650,
#   3769,
#   3890,
#   4013,
#   4138,
#   4265,
#   4394,
#   4525,
#   4658,
#   4793,
#   4930],
#  [1096,
#   1037,
#   980,
#   925,
#   872,
#   821,
#   772,
#   725,
#   680,
#   637,
#   596,
#   557,
#   520,
#   485,
#   452,
#   421,
#   392,
#   365,
#   340,
#   317,
#   296,
#   277,
#   260,
#   245,
#   232,
#   221,
#   212,
#   205,
#   200,
#   197,
#   196,
#   197,
#   200,
#   205,
#   212,
#   221,
#   232,
#   245,
#   260,
#   277,
#   296,
#   317,
#   340,
#   365,
#   392,
#   421,
#   452,
#   485,
#   520,
#   557,
#   596,
#   637,
#   680,
#   725,
#   772,
#   821,
#   872,
#   925,
#   980,
#   1037,
#   1096,
#   1157,
#   1220,
#   1285,
#   1352,
#   1421,
#   1492,
#   1565,
#   1640,
#   1717,
#   1796,
#   1877,
#   1960,
#   2045,
#   2132,
#   2221,
#   2312,
#   2405,
#   2500,
#   2597,
#   2696,
#   2797,
#   2900,
#   3005,
#   3112,
#   3221,
#   3332,
#   3445,
#   3560,
#   3677,
#   3796,
#   3917,
#   4040,
#   4165,
#   4292,
#   4421,
#   4552,
#   4685,
#   4820,
#   4957],
#  [1125,
#   1066,
#   1009,
#   954,
#   901,
#   850,
#   801,
#   754,
#   709,
#   666,
#   625,
#   586,
#   549,
#   514,
#   481,
#   450,
#   421,
#   394,
#   369,
#   346,
#   325,
#   306,
#   289,
#   274,
#   261,
#   250,
#   241,
#   234,
#   229,
#   226,
#   225,
#   226,
#   229,
#   234,
#   241,
#   250,
#   261,
#   274,
#   289,
#   306,
#   325,
#   346,
#   369,
#   394,
#   421,
#   450,
#   481,
#   514,
#   549,
#   586,
#   625,
#   666,
#   709,
#   754,
#   801,
#   850,
#   901,
#   954,
#   1009,
#   1066,
#   1125,
#   1186,
#   1249,
#   1314,
#   1381,
#   1450,
#   1521,
#   1594,
#   1669,
#   1746,
#   1825,
#   1906,
#   1989,
#   2074,
#   2161,
#   2250,
#   2341,
#   2434,
#   2529,
#   2626,
#   2725,
#   2826,
#   2929,
#   3034,
#   3141,
#   3250,
#   3361,
#   3474,
#   3589,
#   3706,
#   3825,
#   3946,
#   4069,
#   4194,
#   4321,
#   4450,
#   4581,
#   4714,
#   4849,
#   4986],
#  [1156,
#   1097,
#   1040,
#   985,
#   932,
#   881,
#   832,
#   785,
#   740,
#   697,
#   656,
#   617,
#   580,
#   545,
#   512,
#   481,
#   452,
#   425,
#   400,
#   377,
#   356,
#   337,
#   320,
#   305,
#   292,
#   281,
#   272,
#   265,
#   260,
#   257,
#   256,
#   257,
#   260,
#   265,
#   272,
#   281,
#   292,
#   305,
#   320,
#   337,
#   356,
#   377,
#   400,
#   425,
#   452,
#   481,
#   512,
#   545,
#   580,
#   617,
#   656,
#   697,
#   740,
#   785,
#   832,
#   881,
#   932,
#   985,
#   1040,
#   1097,
#   1156,
#   1217,
#   1280,
#   1345,
#   1412,
#   1481,
#   1552,
#   1625,
#   1700,
#   1777,
#   1856,
#   1937,
#   2020,
#   2105,
#   2192,
#   2281,
#   2372,
#   2465,
#   2560,
#   2657,
#   2756,
#   2857,
#   2960,
#   3065,
#   3172,
#   3281,
#   3392,
#   3505,
#   3620,
#   3737,
#   3856,
#   3977,
#   4100,
#   4225,
#   4352,
#   4481,
#   4612,
#   4745,
#   4880,
#   5017],
#  [1189,
#   1130,
#   1073,
#   1018,
#   965,
#   914,
#   865,
#   818,
#   773,
#   730,
#   689,
#   650,
#   613,
#   578,
#   545,
#   514,
#   485,
#   458,
#   433,
#   410,
#   389,
#   370,
#   353,
#   338,
#   325,
#   314,
#   305,
#   298,
#   293,
#   290,
#   289,
#   290,
#   293,
#   298,
#   305,
#   314,
#   325,
#   338,
#   353,
#   370,
#   389,
#   410,
#   433,
#   458,
#   485,
#   514,
#   545,
#   578,
#   613,
#   650,
#   689,
#   730,
#   773,
#   818,
#   865,
#   914,
#   965,
#   1018,
#   1073,
#   1130,
#   1189,
#   1250,
#   1313,
#   1378,
#   1445,
#   1514,
#   1585,
#   1658,
#   1733,
#   1810,
#   1889,
#   1970,
#   2053,
#   2138,
#   2225,
#   2314,
#   2405,
#   2498,
#   2593,
#   2690,
#   2789,
#   2890,
#   2993,
#   3098,
#   3205,
#   3314,
#   3425,
#   3538,
#   3653,
#   3770,
#   3889,
#   4010,
#   4133,
#   4258,
#   4385,
#   4514,
#   4645,
#   4778,
#   4913,
#   5050],
#  [1224,
#   1165,
#   1108,
#   1053,
#   1000,
#   949,
#   900,
#   853,
#   808,
#   765,
#   724,
#   685,
#   648,
#   613,
#   580,
#   549,
#   520,
#   493,
#   468,
#   445,
#   424,
#   405,
#   388,
#   373,
#   360,
#   349,
#   340,
#   333,
#   328,
#   325,
#   324,
#   325,
#   328,
#   333,
#   340,
#   349,
#   360,
#   373,
#   388,
#   405,
#   424,
#   445,
#   468,
#   493,
#   520,
#   549,
#   580,
#   613,
#   648,
#   685,
#   724,
#   765,
#   808,
#   853,
#   900,
#   949,
#   1000,
#   1053,
#   1108,
#   1165,
#   1224,
#   1285,
#   1348,
#   1413,
#   1480,
#   1549,
#   1620,
#   1693,
#   1768,
#   1845,
#   1924,
#   2005,
#   2088,
#   2173,
#   2260,
#   2349,
#   2440,
#   2533,
#   2628,
#   2725,
#   2824,
#   2925,
#   3028,
#   3133,
#   3240,
#   3349,
#   3460,
#   3573,
#   3688,
#   3805,
#   3924,
#   4045,
#   4168,
#   4293,
#   4420,
#   4549,
#   4680,
#   4813,
#   4948,
#   5085],
#  [1261,
#   1202,
#   1145,
#   1090,
#   1037,
#   986,
#   937,
#   890,
#   845,
#   802,
#   761,
#   722,
#   685,
#   650,
#   617,
#   586,
#   557,
#   530,
#   505,
#   482,
#   461,
#   442,
#   425,
#   410,
#   397,
#   386,
#   377,
#   370,
#   365,
#   362,
#   361,
#   362,
#   365,
#   370,
#   377,
#   386,
#   397,
#   410,
#   425,
#   442,
#   461,
#   482,
#   505,
#   530,
#   557,
#   586,
#   617,
#   650,
#   685,
#   722,
#   761,
#   802,
#   845,
#   890,
#   937,
#   986,
#   1037,
#   1090,
#   1145,
#   1202,
#   1261,
#   1322,
#   1385,
#   1450,
#   1517,
#   1586,
#   1657,
#   1730,
#   1805,
#   1882,
#   1961,
#   2042,
#   2125,
#   2210,
#   2297,
#   2386,
#   2477,
#   2570,
#   2665,
#   2762,
#   2861,
#   2962,
#   3065,
#   3170,
#   3277,
#   3386,
#   3497,
#   3610,
#   3725,
#   3842,
#   3961,
#   4082,
#   4205,
#   4330,
#   4457,
#   4586,
#   4717,
#   4850,
#   4985,
#   5122],
#  [1300,
#   1241,
#   1184,
#   1129,
#   1076,
#   1025,
#   976,
#   929,
#   884,
#   841,
#   800,
#   761,
#   724,
#   689,
#   656,
#   625,
#   596,
#   569,
#   544,
#   521,
#   500,
#   481,
#   464,
#   449,
#   436,
#   425,
#   416,
#   409,
#   404,
#   401,
#   400,
#   401,
#   404,
#   409,
#   416,
#   425,
#   436,
#   449,
#   464,
#   481,
#   500,
#   521,
#   544,
#   569,
#   596,
#   625,
#   656,
#   689,
#   724,
#   761,
#   800,
#   841,
#   884,
#   929,
#   976,
#   1025,
#   1076,
#   1129,
#   1184,
#   1241,
#   1300,
#   1361,
#   1424,
#   1489,
#   1556,
#   1625,
#   1696,
#   1769,
#   1844,
#   1921,
#   2000,
#   2081,
#   2164,
#   2249,
#   2336,
#   2425,
#   2516,
#   2609,
#   2704,
#   2801,
#   2900,
#   3001,
#   3104,
#   3209,
#   3316,
#   3425,
#   3536,
#   3649,
#   3764,
#   3881,
#   4000,
#   4121,
#   4244,
#   4369,
#   4496,
#   4625,
#   4756,
#   4889,
#   5024,
#   5161],
#  [1341,
#   1282,
#   1225,
#   1170,
#   1117,
#   1066,
#   1017,
#   970,
#   925,
#   882,
#   841,
#   802,
#   765,
#   730,
#   697,
#   666,
#   637,
#   610,
#   585,
#   562,
#   541,
#   522,
#   505,
#   490,
#   477,
#   466,
#   457,
#   450,
#   445,
#   442,
#   441,
#   442,
#   445,
#   450,
#   457,
#   466,
#   477,
#   490,
#   505,
#   522,
#   541,
#   562,
#   585,
#   610,
#   637,
#   666,
#   697,
#   730,
#   765,
#   802,
#   841,
#   882,
#   925,
#   970,
#   1017,
#   1066,
#   1117,
#   1170,
#   1225,
#   1282,
#   1341,
#   1402,
#   1465,
#   1530,
#   1597,
#   1666,
#   1737,
#   1810,
#   1885,
#   1962,
#   2041,
#   2122,
#   2205,
#   2290,
#   2377,
#   2466,
#   2557,
#   2650,
#   2745,
#   2842,
#   2941,
#   3042,
#   3145,
#   3250,
#   3357,
#   3466,
#   3577,
#   3690,
#   3805,
#   3922,
#   4041,
#   4162,
#   4285,
#   4410,
#   4537,
#   4666,
#   4797,
#   4930,
#   5065,
#   5202],
#  [1384,
#   1325,
#   1268,
#   1213,
#   1160,
#   1109,
#   1060,
#   1013,
#   968,
#   925,
#   884,
#   845,
#   808,
#   773,
#   740,
#   709,
#   680,
#   653,
#   628,
#   605,
#   584,
#   565,
#   548,
#   533,
#   520,
#   509,
#   500,
#   493,
#   488,
#   485,
#   484,
#   485,
#   488,
#   493,
#   500,
#   509,
#   520,
#   533,
#   548,
#   565,
#   584,
#   605,
#   628,
#   653,
#   680,
#   709,
#   740,
#   773,
#   808,
#   845,
#   884,
#   925,
#   968,
#   1013,
#   1060,
#   1109,
#   1160,
#   1213,
#   1268,
#   1325,
#   1384,
#   1445,
#   1508,
#   1573,
#   1640,
#   1709,
#   1780,
#   1853,
#   1928,
#   2005,
#   2084,
#   2165,
#   2248,
#   2333,
#   2420,
#   2509,
#   2600,
#   2693,
#   2788,
#   2885,
#   2984,
#   3085,
#   3188,
#   3293,
#   3400,
#   3509,
#   3620,
#   3733,
#   3848,
#   3965,
#   4084,
#   4205,
#   4328,
#   4453,
#   4580,
#   4709,
#   4840,
#   4973,
#   5108,
#   5245],
#  [1429,
#   1370,
#   1313,
#   1258,
#   1205,
#   1154,
#   1105,
#   1058,
#   1013,
#   970,
#   929,
#   890,
#   853,
#   818,
#   785,
#   754,
#   725,
#   698,
#   673,
#   650,
#   629,
#   610,
#   593,
#   578,
#   565,
#   554,
#   545,
#   538,
#   533,
#   530,
#   529,
#   530,
#   533,
#   538,
#   545,
#   554,
#   565,
#   578,
#   593,
#   610,
#   629,
#   650,
#   673,
#   698,
#   725,
#   754,
#   785,
#   818,
#   853,
#   890,
#   929,
#   970,
#   1013,
#   1058,
#   1105,
#   1154,
#   1205,
#   1258,
#   1313,
#   1370,
#   1429,
#   1490,
#   1553,
#   1618,
#   1685,
#   1754,
#   1825,
#   1898,
#   1973,
#   2050,
#   2129,
#   2210,
#   2293,
#   2378,
#   2465,
#   2554,
#   2645,
#   2738,
#   2833,
#   2930,
#   3029,
#   3130,
#   3233,
#   3338,
#   3445,
#   3554,
#   3665,
#   3778,
#   3893,
#   4010,
#   4129,
#   4250,
#   4373,
#   4498,
#   4625,
#   4754,
#   4885,
#   5018,
#   5153,
#   5290],
#  [1476,
#   1417,
#   1360,
#   1305,
#   1252,
#   1201,
#   1152,
#   1105,
#   1060,
#   1017,
#   976,
#   937,
#   900,
#   865,
#   832,
#   801,
#   772,
#   745,
#   720,
#   697,
#   676,
#   657,
#   640,
#   625,
#   612,
#   601,
#   592,
#   585,
#   580,
#   577,
#   576,
#   577,
#   580,
#   585,
#   592,
#   601,
#   612,
#   625,
#   640,
#   657,
#   676,
#   697,
#   720,
#   745,
#   772,
#   801,
#   832,
#   865,
#   900,
#   937,
#   976,
#   1017,
#   1060,
#   1105,
#   1152,
#   1201,
#   1252,
#   1305,
#   1360,
#   1417,
#   1476,
#   1537,
#   1600,
#   1665,
#   1732,
#   1801,
#   1872,
#   1945,
#   2020,
#   2097,
#   2176,
#   2257,
#   2340,
#   2425,
#   2512,
#   2601,
#   2692,
#   2785,
#   2880,
#   2977,
#   3076,
#   3177,
#   3280,
#   3385,
#   3492,
#   3601,
#   3712,
#   3825,
#   3940,
#   4057,
#   4176,
#   4297,
#   4420,
#   4545,
#   4672,
#   4801,
#   4932,
#   5065,
#   5200,
#   5337],
#  [1525,
#   1466,
#   1409,
#   1354,
#   1301,
#   1250,
#   1201,
#   1154,
#   1109,
#   1066,
#   1025,
#   986,
#   949,
#   914,
#   881,
#   850,
#   821,
#   794,
#   769,
#   746,
#   725,
#   706,
#   689,
#   674,
#   661,
#   650,
#   641,
#   634,
#   629,
#   626,
#   625,
#   626,
#   629,
#   634,
#   641,
#   650,
#   661,
#   674,
#   689,
#   706,
#   725,
#   746,
#   769,
#   794,
#   821,
#   850,
#   881,
#   914,
#   949,
#   986,
#   1025,
#   1066,
#   1109,
#   1154,
#   1201,
#   1250,
#   1301,
#   1354,
#   1409,
#   1466,
#   1525,
#   1586,
#   1649,
#   1714,
#   1781,
#   1850,
#   1921,
#   1994,
#   2069,
#   2146,
#   2225,
#   2306,
#   2389,
#   2474,
#   2561,
#   2650,
#   2741,
#   2834,
#   2929,
#   3026,
#   3125,
#   3226,
#   3329,
#   3434,
#   3541,
#   3650,
#   3761,
#   3874,
#   3989,
#   4106,
#   4225,
#   4346,
#   4469,
#   4594,
#   4721,
#   4850,
#   4981,
#   5114,
#   5249,
#   5386],
#  [1576,
#   1517,
#   1460,
#   1405,
#   1352,
#   1301,
#   1252,
#   1205,
#   1160,
#   1117,
#   1076,
#   1037,
#   1000,
#   965,
#   932,
#   901,
#   872,
#   845,
#   820,
#   797,
#   776,
#   757,
#   740,
#   725,
#   712,
#   701,
#   692,
#   685,
#   680,
#   677,
#   676,
#   677,
#   680,
#   685,
#   692,
#   701,
#   712,
#   725,
#   740,
#   757,
#   776,
#   797,
#   820,
#   845,
#   872,
#   901,
#   932,
#   965,
#   1000,
#   1037,
#   1076,
#   1117,
#   1160,
#   1205,
#   1252,
#   1301,
#   1352,
#   1405,
#   1460,
#   1517,
#   1576,
#   1637,
#   1700,
#   1765,
#   1832,
#   1901,
#   1972,
#   2045,
#   2120,
#   2197,
#   2276,
#   2357,
#   2440,
#   2525,
#   2612,
#   2701,
#   2792,
#   2885,
#   2980,
#   3077,
#   3176,
#   3277,
#   3380,
#   3485,
#   3592,
#   3701,
#   3812,
#   3925,
#   4040,
#   4157,
#   4276,
#   4397,
#   4520,
#   4645,
#   4772,
#   4901,
#   5032,
#   5165,
#   5300,
#   5437],
#  [1629,
#   1570,
#   1513,
#   1458,
#   1405,
#   1354,
#   1305,
#   1258,
#   1213,
#   1170,
#   1129,
#   1090,
#   1053,
#   1018,
#   985,
#   954,
#   925,
#   898,
#   873,
#   850,
#   829,
#   810,
#   793,
#   778,
#   765,
#   754,
#   745,
#   738,
#   733,
#   730,
#   729,
#   730,
#   733,
#   738,
#   745,
#   754,
#   765,
#   778,
#   793,
#   810,
#   829,
#   850,
#   873,
#   898,
#   925,
#   954,
#   985,
#   1018,
#   1053,
#   1090,
#   1129,
#   1170,
#   1213,
#   1258,
#   1305,
#   1354,
#   1405,
#   1458,
#   1513,
#   1570,
#   1629,
#   1690,
#   1753,
#   1818,
#   1885,
#   1954,
#   2025,
#   2098,
#   2173,
#   2250,
#   2329,
#   2410,
#   2493,
#   2578,
#   2665,
#   2754,
#   2845,
#   2938,
#   3033,
#   3130,
#   3229,
#   3330,
#   3433,
#   3538,
#   3645,
#   3754,
#   3865,
#   3978,
#   4093,
#   4210,
#   4329,
#   4450,
#   4573,
#   4698,
#   4825,
#   4954,
#   5085,
#   5218,
#   5353,
#   5490],
#  [1684,
#   1625,
#   1568,
#   1513,
#   1460,
#   1409,
#   1360,
#   1313,
#   1268,
#   1225,
#   1184,
#   1145,
#   1108,
#   1073,
#   1040,
#   1009,
#   980,
#   953,
#   928,
#   905,
#   884,
#   865,
#   848,
#   833,
#   820,
#   809,
#   800,
#   793,
#   788,
#   785,
#   784,
#   785,
#   788,
#   793,
#   800,
#   809,
#   820,
#   833,
#   848,
#   865,
#   884,
#   905,
#   928,
#   953,
#   980,
#   1009,
#   1040,
#   1073,
#   1108,
#   1145,
#   1184,
#   1225,
#   1268,
#   1313,
#   1360,
#   1409,
#   1460,
#   1513,
#   1568,
#   1625,
#   1684,
#   1745,
#   1808,
#   1873,
#   1940,
#   2009,
#   2080,
#   2153,
#   2228,
#   2305,
#   2384,
#   2465,
#   2548,
#   2633,
#   2720,
#   2809,
#   2900,
#   2993,
#   3088,
#   3185,
#   3284,
#   3385,
#   3488,
#   3593,
#   3700,
#   3809,
#   3920,
#   4033,
#   4148,
#   4265,
#   4384,
#   4505,
#   4628,
#   4753,
#   4880,
#   5009,
#   5140,
#   5273,
#   5408,
#   5545],
#  [1741,
#   1682,
#   1625,
#   1570,
#   1517,
#   1466,
#   1417,
#   1370,
#   1325,
#   1282,
#   1241,
#   1202,
#   1165,
#   1130,
#   1097,
#   1066,
#   1037,
#   1010,
#   985,
#   962,
#   941,
#   922,
#   905,
#   890,
#   877,
#   866,
#   857,
#   850,
#   845,
#   842,
#   841,
#   842,
#   845,
#   850,
#   857,
#   866,
#   877,
#   890,
#   905,
#   922,
#   941,
#   962,
#   985,
#   1010,
#   1037,
#   1066,
#   1097,
#   1130,
#   1165,
#   1202,
#   1241,
#   1282,
#   1325,
#   1370,
#   1417,
#   1466,
#   1517,
#   1570,
#   1625,
#   1682,
#   1741,
#   1802,
#   1865,
#   1930,
#   1997,
#   2066,
#   2137,
#   2210,
#   2285,
#   2362,
#   2441,
#   2522,
#   2605,
#   2690,
#   2777,
#   2866,
#   2957,
#   3050,
#   3145,
#   3242,
#   3341,
#   3442,
#   3545,
#   3650,
#   3757,
#   3866,
#   3977,
#   4090,
#   4205,
#   4322,
#   4441,
#   4562,
#   4685,
#   4810,
#   4937,
#   5066,
#   5197,
#   5330,
#   5465,
#   5602],
#  [1800,
#   1741,
#   1684,
#   1629,
#   1576,
#   1525,
#   1476,
#   1429,
#   1384,
#   1341,
#   1300,
#   1261,
#   1224,
#   1189,
#   1156,
#   1125,
#   1096,
#   1069,
#   1044,
#   1021,
#   1000,
#   981,
#   964,
#   949,
#   936,
#   925,
#   916,
#   909,
#   904,
#   901,
#   900,
#   901,
#   904,
#   909,
#   916,
#   925,
#   936,
#   949,
#   964,
#   981,
#   1000,
#   1021,
#   1044,
#   1069,
#   1096,
#   1125,
#   1156,
#   1189,
#   1224,
#   1261,
#   1300,
#   1341,
#   1384,
#   1429,
#   1476,
#   1525,
#   1576,
#   1629,
#   1684,
#   1741,
#   1800,
#   1861,
#   1924,
#   1989,
#   2056,
#   2125,
#   2196,
#   2269,
#   2344,
#   2421,
#   2500,
#   2581,
#   2664,
#   2749,
#   2836,
#   2925,
#   3016,
#   3109,
#   3204,
#   3301,
#   3400,
#   3501,
#   3604,
#   3709,
#   3816,
#   3925,
#   4036,
#   4149,
#   4264,
#   4381,
#   4500,
#   4621,
#   4744,
#   4869,
#   4996,
#   5125,
#   5256,
#   5389,
#   5524,
#   5661],
#  [1861,
#   1802,
#   1745,
#   1690,
#   1637,
#   1586,
#   1537,
#   1490,
#   1445,
#   1402,
#   1361,
#   1322,
#   1285,
#   1250,
#   1217,
#   1186,
#   1157,
#   1130,
#   1105,
#   1082,
#   1061,
#   1042,
#   1025,
#   1010,
#   997,
#   986,
#   977,
#   970,
#   965,
#   962,
#   961,
#   962,
#   965,
#   970,
#   977,
#   986,
#   997,
#   1010,
#   1025,
#   1042,
#   1061,
#   1082,
#   1105,
#   1130,
#   1157,
#   1186,
#   1217,
#   1250,
#   1285,
#   1322,
#   1361,
#   1402,
#   1445,
#   1490,
#   1537,
#   1586,
#   1637,
#   1690,
#   1745,
#   1802,
#   1861,
#   1922,
#   1985,
#   2050,
#   2117,
#   2186,
#   2257,
#   2330,
#   2405,
#   2482,
#   2561,
#   2642,
#   2725,
#   2810,
#   2897,
#   2986,
#   3077,
#   3170,
#   3265,
#   3362,
#   3461,
#   3562,
#   3665,
#   3770,
#   3877,
#   3986,
#   4097,
#   4210,
#   4325,
#   4442,
#   4561,
#   4682,
#   4805,
#   4930,
#   5057,
#   5186,
#   5317,
#   5450,
#   5585,
#   5722],
#  [1924,
#   1865,
#   1808,
#   1753,
#   1700,
#   1649,
#   1600,
#   1553,
#   1508,
#   1465,
#   1424,
#   1385,
#   1348,
#   1313,
#   1280,
#   1249,
#   1220,
#   1193,
#   1168,
#   1145,
#   1124,
#   1105,
#   1088,
#   1073,
#   1060,
#   1049,
#   1040,
#   1033,
#   1028,
#   1025,
#   1024,
#   1025,
#   1028,
#   1033,
#   1040,
#   1049,
#   1060,
#   1073,
#   1088,
#   1105,
#   1124,
#   1145,
#   1168,
#   1193,
#   1220,
#   1249,
#   1280,
#   1313,
#   1348,
#   1385,
#   1424,
#   1465,
#   1508,
#   1553,
#   1600,
#   1649,
#   1700,
#   1753,
#   1808,
#   1865,
#   1924,
#   1985,
#   2048,
#   2113,
#   2180,
#   2249,
#   2320,
#   2393,
#   2468,
#   2545,
#   2624,
#   2705,
#   2788,
#   2873,
#   2960,
#   3049,
#   3140,
#   3233,
#   3328,
#   3425,
#   3524,
#   3625,
#   3728,
#   3833,
#   3940,
#   4049,
#   4160,
#   4273,
#   4388,
#   4505,
#   4624,
#   4745,
#   4868,
#   4993,
#   5120,
#   5249,
#   5380,
#   5513,
#   5648,
#   5785],
#  [1989,
#   1930,
#   1873,
#   1818,
#   1765,
#   1714,
#   1665,
#   1618,
#   1573,
#   1530,
#   1489,
#   1450,
#   1413,
#   1378,
#   1345,
#   1314,
#   1285,
#   1258,
#   1233,
#   1210,
#   1189,
#   1170,
#   1153,
#   1138,
#   1125,
#   1114,
#   1105,
#   1098,
#   1093,
#   1090,
#   1089,
#   1090,
#   1093,
#   1098,
#   1105,
#   1114,
#   1125,
#   1138,
#   1153,
#   1170,
#   1189,
#   1210,
#   1233,
#   1258,
#   1285,
#   1314,
#   1345,
#   1378,
#   1413,
#   1450,
#   1489,
#   1530,
#   1573,
#   1618,
#   1665,
#   1714,
#   1765,
#   1818,
#   1873,
#   1930,
#   1989,
#   2050,
#   2113,
#   2178,
#   2245,
#   2314,
#   2385,
#   2458,
#   2533,
#   2610,
#   2689,
#   2770,
#   2853,
#   2938,
#   3025,
#   3114,
#   3205,
#   3298,
#   3393,
#   3490,
#   3589,
#   3690,
#   3793,
#   3898,
#   4005,
#   4114,
#   4225,
#   4338,
#   4453,
#   4570,
#   4689,
#   4810,
#   4933,
#   5058,
#   5185,
#   5314,
#   5445,
#   5578,
#   5713,
#   5850],
#  [2056,
#   1997,
#   1940,
#   1885,
#   1832,
#   1781,
#   1732,
#   1685,
#   1640,
#   1597,
#   1556,
#   1517,
#   1480,
#   1445,
#   1412,
#   1381,
#   1352,
#   1325,
#   1300,
#   1277,
#   1256,
#   1237,
#   1220,
#   1205,
#   1192,
#   1181,
#   1172,
#   1165,
#   1160,
#   1157,
#   1156,
#   1157,
#   1160,
#   1165,
#   1172,
#   1181,
#   1192,
#   1205,
#   1220,
#   1237,
#   1256,
#   1277,
#   1300,
#   1325,
#   1352,
#   1381,
#   1412,
#   1445,
#   1480,
#   1517,
#   1556,
#   1597,
#   1640,
#   1685,
#   1732,
#   1781,
#   1832,
#   1885,
#   1940,
#   1997,
#   2056,
#   2117,
#   2180,
#   2245,
#   2312,
#   2381,
#   2452,
#   2525,
#   2600,
#   2677,
#   2756,
#   2837,
#   2920,
#   3005,
#   3092,
#   3181,
#   3272,
#   3365,
#   3460,
#   3557,
#   3656,
#   3757,
#   3860,
#   3965,
#   4072,
#   4181,
#   4292,
#   4405,
#   4520,
#   4637,
#   4756,
#   4877,
#   5000,
#   5125,
#   5252,
#   5381,
#   5512,
#   5645,
#   5780,
#   5917],
#  [2125,
#   2066,
#   2009,
#   1954,
#   1901,
#   1850,
#   1801,
#   1754,
#   1709,
#   1666,
#   1625,
#   1586,
#   1549,
#   1514,
#   1481,
#   1450,
#   1421,
#   1394,
#   1369,
#   1346,
#   1325,
#   1306,
#   1289,
#   1274,
#   1261,
#   1250,
#   1241,
#   1234,
#   1229,
#   1226,
#   1225,
#   1226,
#   1229,
#   1234,
#   1241,
#   1250,
#   1261,
#   1274,
#   1289,
#   1306,
#   1325,
#   1346,
#   1369,
#   1394,
#   1421,
#   1450,
#   1481,
#   1514,
#   1549,
#   1586,
#   1625,
#   1666,
#   1709,
#   1754,
#   1801,
#   1850,
#   1901,
#   1954,
#   2009,
#   2066,
#   2125,
#   2186,
#   2249,
#   2314,
#   2381,
#   2450,
#   2521,
#   2594,
#   2669,
#   2746,
#   2825,
#   2906,
#   2989,
#   3074,
#   3161,
#   3250,
#   3341,
#   3434,
#   3529,
#   3626,
#   3725,
#   3826,
#   3929,
#   4034,
#   4141,
#   4250,
#   4361,
#   4474,
#   4589,
#   4706,
#   4825,
#   4946,
#   5069,
#   5194,
#   5321,
#   5450,
#   5581,
#   5714,
#   5849,
#   5986],
#  [2196,
#   2137,
#   2080,
#   2025,
#   1972,
#   1921,
#   1872,
#   1825,
#   1780,
#   1737,
#   1696,
#   1657,
#   1620,
#   1585,
#   1552,
#   1521,
#   1492,
#   1465,
#   1440,
#   1417,
#   1396,
#   1377,
#   1360,
#   1345,
#   1332,
#   1321,
#   1312,
#   1305,
#   1300,
#   1297,
#   1296,
#   1297,
#   1300,
#   1305,
#   1312,
#   1321,
#   1332,
#   1345,
#   1360,
#   1377,
#   1396,
#   1417,
#   1440,
#   1465,
#   1492,
#   1521,
#   1552,
#   1585,
#   1620,
#   1657,
#   1696,
#   1737,
#   1780,
#   1825,
#   1872,
#   1921,
#   1972,
#   2025,
#   2080,
#   2137,
#   2196,
#   2257,
#   2320,
#   2385,
#   2452,
#   2521,
#   2592,
#   2665,
#   2740,
#   2817,
#   2896,
#   2977,
#   3060,
#   3145,
#   3232,
#   3321,
#   3412,
#   3505,
#   3600,
#   3697,
#   3796,
#   3897,
#   4000,
#   4105,
#   4212,
#   4321,
#   4432,
#   4545,
#   4660,
#   4777,
#   4896,
#   5017,
#   5140,
#   5265,
#   5392,
#   5521,
#   5652,
#   5785,
#   5920,
#   6057],
#  [2269,
#   2210,
#   2153,
#   2098,
#   2045,
#   1994,
#   1945,
#   1898,
#   1853,
#   1810,
#   1769,
#   1730,
#   1693,
#   1658,
#   1625,
#   1594,
#   1565,
#   1538,
#   1513,
#   1490,
#   1469,
#   1450,
#   1433,
#   1418,
#   1405,
#   1394,
#   1385,
#   1378,
#   1373,
#   1370,
#   1369,
#   1370,
#   1373,
#   1378,
#   1385,
#   1394,
#   1405,
#   1418,
#   1433,
#   1450,
#   1469,
#   1490,
#   1513,
#   1538,
#   1565,
#   1594,
#   1625,
#   1658,
#   1693,
#   1730,
#   1769,
#   1810,
#   1853,
#   1898,
#   1945,
#   1994,
#   2045,
#   2098,
#   2153,
#   2210,
#   2269,
#   2330,
#   2393,
#   2458,
#   2525,
#   2594,
#   2665,
#   2738,
#   2813,
#   2890,
#   2969,
#   3050,
#   3133,
#   3218,
#   3305,
#   3394,
#   3485,
#   3578,
#   3673,
#   3770,
#   3869,
#   3970,
#   4073,
#   4178,
#   4285,
#   4394,
#   4505,
#   4618,
#   4733,
#   4850,
#   4969,
#   5090,
#   5213,
#   5338,
#   5465,
#   5594,
#   5725,
#   5858,
#   5993,
#   6130],
#  [2344,
#   2285,
#   2228,
#   2173,
#   2120,
#   2069,
#   2020,
#   1973,
#   1928,
#   1885,
#   1844,
#   1805,
#   1768,
#   1733,
#   1700,
#   1669,
#   1640,
#   1613,
#   1588,
#   1565,
#   1544,
#   1525,
#   1508,
#   1493,
#   1480,
#   1469,
#   1460,
#   1453,
#   1448,
#   1445,
#   1444,
#   1445,
#   1448,
#   1453,
#   1460,
#   1469,
#   1480,
#   1493,
#   1508,
#   1525,
#   1544,
#   1565,
#   1588,
#   1613,
#   1640,
#   1669,
#   1700,
#   1733,
#   1768,
#   1805,
#   1844,
#   1885,
#   1928,
#   1973,
#   2020,
#   2069,
#   2120,
#   2173,
#   2228,
#   2285,
#   2344,
#   2405,
#   2468,
#   2533,
#   2600,
#   2669,
#   2740,
#   2813,
#   2888,
#   2965,
#   3044,
#   3125,
#   3208,
#   3293,
#   3380,
#   3469,
#   3560,
#   3653,
#   3748,
#   3845,
#   3944,
#   4045,
#   4148,
#   4253,
#   4360,
#   4469,
#   4580,
#   4693,
#   4808,
#   4925,
#   5044,
#   5165,
#   5288,
#   5413,
#   5540,
#   5669,
#   5800,
#   5933,
#   6068,
#   6205],
#  [2421,
#   2362,
#   2305,
#   2250,
#   2197,
#   2146,
#   2097,
#   2050,
#   2005,
#   1962,
#   1921,
#   1882,
#   1845,
#   1810,
#   1777,
#   1746,
#   1717,
#   1690,
#   1665,
#   1642,
#   1621,
#   1602,
#   1585,
#   1570,
#   1557,
#   1546,
#   1537,
#   1530,
#   1525,
#   1522,
#   1521,
#   1522,
#   1525,
#   1530,
#   1537,
#   1546,
#   1557,
#   1570,
#   1585,
#   1602,
#   1621,
#   1642,
#   1665,
#   1690,
#   1717,
#   1746,
#   1777,
#   1810,
#   1845,
#   1882,
#   1921,
#   1962,
#   2005,
#   2050,
#   2097,
#   2146,
#   2197,
#   2250,
#   2305,
#   2362,
#   2421,
#   2482,
#   2545,
#   2610,
#   2677,
#   2746,
#   2817,
#   2890,
#   2965,
#   3042,
#   3121,
#   3202,
#   3285,
#   3370,
#   3457,
#   3546,
#   3637,
#   3730,
#   3825,
#   3922,
#   4021,
#   4122,
#   4225,
#   4330,
#   4437,
#   4546,
#   4657,
#   4770,
#   4885,
#   5002,
#   5121,
#   5242,
#   5365,
#   5490,
#   5617,
#   5746,
#   5877,
#   6010,
#   6145,
#   6282],
#  [2500,
#   2441,
#   2384,
#   2329,
#   2276,
#   2225,
#   2176,
#   2129,
#   2084,
#   2041,
#   2000,
#   1961,
#   1924,
#   1889,
#   1856,
#   1825,
#   1796,
#   1769,
#   1744,
#   1721,
#   1700,
#   1681,
#   1664,
#   1649,
#   1636,
#   1625,
#   1616,
#   1609,
#   1604,
#   1601,
#   1600,
#   1601,
#   1604,
#   1609,
#   1616,
#   1625,
#   1636,
#   1649,
#   1664,
#   1681,
#   1700,
#   1721,
#   1744,
#   1769,
#   1796,
#   1825,
#   1856,
#   1889,
#   1924,
#   1961,
#   2000,
#   2041,
#   2084,
#   2129,
#   2176,
#   2225,
#   2276,
#   2329,
#   2384,
#   2441,
#   2500,
#   2561,
#   2624,
#   2689,
#   2756,
#   2825,
#   2896,
#   2969,
#   3044,
#   3121,
#   3200,
#   3281,
#   3364,
#   3449,
#   3536,
#   3625,
#   3716,
#   3809,
#   3904,
#   4001,
#   4100,
#   4201,
#   4304,
#   4409,
#   4516,
#   4625,
#   4736,
#   4849,
#   4964,
#   5081,
#   5200,
#   5321,
#   5444,
#   5569,
#   5696,
#   5825,
#   5956,
#   6089,
#   6224,
#   6361],
#  [2581,
#   2522,
#   2465,
#   2410,
#   2357,
#   2306,
#   2257,
#   2210,
#   2165,
#   2122,
#   2081,
#   2042,
#   2005,
#   1970,
#   1937,
#   1906,
#   1877,
#   1850,
#   1825,
#   1802,
#   1781,
#   1762,
#   1745,
#   1730,
#   1717,
#   1706,
#   1697,
#   1690,
#   1685,
#   1682,
#   1681,
#   1682,
#   1685,
#   1690,
#   1697,
#   1706,
#   1717,
#   1730,
#   1745,
#   1762,
#   1781,
#   1802,
#   1825,
#   1850,
#   1877,
#   1906,
#   1937,
#   1970,
#   2005,
#   2042,
#   2081,
#   2122,
#   2165,
#   2210,
#   2257,
#   2306,
#   2357,
#   2410,
#   2465,
#   2522,
#   2581,
#   2642,
#   2705,
#   2770,
#   2837,
#   2906,
#   2977,
#   3050,
#   3125,
#   3202,
#   3281,
#   3362,
#   3445,
#   3530,
#   3617,
#   3706,
#   3797,
#   3890,
#   3985,
#   4082,
#   4181,
#   4282,
#   4385,
#   4490,
#   4597,
#   4706,
#   4817,
#   4930,
#   5045,
#   5162,
#   5281,
#   5402,
#   5525,
#   5650,
#   5777,
#   5906,
#   6037,
#   6170,
#   6305,
#   6442],
#  [2664,
#   2605,
#   2548,
#   2493,
#   2440,
#   2389,
#   2340,
#   2293,
#   2248,
#   2205,
#   2164,
#   2125,
#   2088,
#   2053,
#   2020,
#   1989,
#   1960,
#   1933,
#   1908,
#   1885,
#   1864,
#   1845,
#   1828,
#   1813,
#   1800,
#   1789,
#   1780,
#   1773,
#   1768,
#   1765,
#   1764,
#   1765,
#   1768,
#   1773,
#   1780,
#   1789,
#   1800,
#   1813,
#   1828,
#   1845,
#   1864,
#   1885,
#   1908,
#   1933,
#   1960,
#   1989,
#   2020,
#   2053,
#   2088,
#   2125,
#   2164,
#   2205,
#   2248,
#   2293,
#   2340,
#   2389,
#   2440,
#   2493,
#   2548,
#   2605,
#   2664,
#   2725,
#   2788,
#   2853,
#   2920,
#   2989,
#   3060,
#   3133,
#   3208,
#   3285,
#   3364,
#   3445,
#   3528,
#   3613,
#   3700,
#   3789,
#   3880,
#   3973,
#   4068,
#   4165,
#   4264,
#   4365,
#   4468,
#   4573,
#   4680,
#   4789,
#   4900,
#   5013,
#   5128,
#   5245,
#   5364,
#   5485,
#   5608,
#   5733,
#   5860,
#   5989,
#   6120,
#   6253,
#   6388,
#   6525],
#  [2749,
#   2690,
#   2633,
#   2578,
#   2525,
#   2474,
#   2425,
#   2378,
#   2333,
#   2290,
#   2249,
#   2210,
#   2173,
#   2138,
#   2105,
#   2074,
#   2045,
#   2018,
#   1993,
#   1970,
#   1949,
#   1930,
#   1913,
#   1898,
#   1885,
#   1874,
#   1865,
#   1858,
#   1853,
#   1850,
#   1849,
#   1850,
#   1853,
#   1858,
#   1865,
#   1874,
#   1885,
#   1898,
#   1913,
#   1930,
#   1949,
#   1970,
#   1993,
#   2018,
#   2045,
#   2074,
#   2105,
#   2138,
#   2173,
#   2210,
#   2249,
#   2290,
#   2333,
#   2378,
#   2425,
#   2474,
#   2525,
#   2578,
#   2633,
#   2690,
#   2749,
#   2810,
#   2873,
#   2938,
#   3005,
#   3074,
#   3145,
#   3218,
#   3293,
#   3370,
#   3449,
#   3530,
#   3613,
#   3698,
#   3785,
#   3874,
#   3965,
#   4058,
#   4153,
#   4250,
#   4349,
#   4450,
#   4553,
#   4658,
#   4765,
#   4874,
#   4985,
#   5098,
#   5213,
#   5330,
#   5449,
#   5570,
#   5693,
#   5818,
#   5945,
#   6074,
#   6205,
#   6338,
#   6473,
#   6610],
#  [2836,
#   2777,
#   2720,
#   2665,
#   2612,
#   2561,
#   2512,
#   2465,
#   2420,
#   2377,
#   2336,
#   2297,
#   2260,
#   2225,
#   2192,
#   2161,
#   2132,
#   2105,
#   2080,
#   2057,
#   2036,
#   2017,
#   2000,
#   1985,
#   1972,
#   1961,
#   1952,
#   1945,
#   1940,
#   1937,
#   1936,
#   1937,
#   1940,
#   1945,
#   1952,
#   1961,
#   1972,
#   1985,
#   2000,
#   2017,
#   2036,
#   2057,
#   2080,
#   2105,
#   2132,
#   2161,
#   2192,
#   2225,
#   2260,
#   2297,
#   2336,
#   2377,
#   2420,
#   2465,
#   2512,
#   2561,
#   2612,
#   2665,
#   2720,
#   2777,
#   2836,
#   2897,
#   2960,
#   3025,
#   3092,
#   3161,
#   3232,
#   3305,
#   3380,
#   3457,
#   3536,
#   3617,
#   3700,
#   3785,
#   3872,
#   3961,
#   4052,
#   4145,
#   4240,
#   4337,
#   4436,
#   4537,
#   4640,
#   4745,
#   4852,
#   4961,
#   5072,
#   5185,
#   5300,
#   5417,
#   5536,
#   5657,
#   5780,
#   5905,
#   6032,
#   6161,
#   6292,
#   6425,
#   6560,
#   6697],
#  [2925,
#   2866,
#   2809,
#   2754,
#   2701,
#   2650,
#   2601,
#   2554,
#   2509,
#   2466,
#   2425,
#   2386,
#   2349,
#   2314,
#   2281,
#   2250,
#   2221,
#   2194,
#   2169,
#   2146,
#   2125,
#   2106,
#   2089,
#   2074,
#   2061,
#   2050,
#   2041,
#   2034,
#   2029,
#   2026,
#   2025,
#   2026,
#   2029,
#   2034,
#   2041,
#   2050,
#   2061,
#   2074,
#   2089,
#   2106,
#   2125,
#   2146,
#   2169,
#   2194,
#   2221,
#   2250,
#   2281,
#   2314,
#   2349,
#   2386,
#   2425,
#   2466,
#   2509,
#   2554,
#   2601,
#   2650,
#   2701,
#   2754,
#   2809,
#   2866,
#   2925,
#   2986,
#   3049,
#   3114,
#   3181,
#   3250,
#   3321,
#   3394,
#   3469,
#   3546,
#   3625,
#   3706,
#   3789,
#   3874,
#   3961,
#   4050,
#   4141,
#   4234,
#   4329,
#   4426,
#   4525,
#   4626,
#   4729,
#   4834,
#   4941,
#   5050,
#   5161,
#   5274,
#   5389,
#   5506,
#   5625,
#   5746,
#   5869,
#   5994,
#   6121,
#   6250,
#   6381,
#   6514,
#   6649,
#   6786],
#  [3016,
#   2957,
#   2900,
#   2845,
#   2792,
#   2741,
#   2692,
#   2645,
#   2600,
#   2557,
#   2516,
#   2477,
#   2440,
#   2405,
#   2372,
#   2341,
#   2312,
#   2285,
#   2260,
#   2237,
#   2216,
#   2197,
#   2180,
#   2165,
#   2152,
#   2141,
#   2132,
#   2125,
#   2120,
#   2117,
#   2116,
#   2117,
#   2120,
#   2125,
#   2132,
#   2141,
#   2152,
#   2165,
#   2180,
#   2197,
#   2216,
#   2237,
#   2260,
#   2285,
#   2312,
#   2341,
#   2372,
#   2405,
#   2440,
#   2477,
#   2516,
#   2557,
#   2600,
#   2645,
#   2692,
#   2741,
#   2792,
#   2845,
#   2900,
#   2957,
#   3016,
#   3077,
#   3140,
#   3205,
#   3272,
#   3341,
#   3412,
#   3485,
#   3560,
#   3637,
#   3716,
#   3797,
#   3880,
#   3965,
#   4052,
#   4141,
#   4232,
#   4325,
#   4420,
#   4517,
#   4616,
#   4717,
#   4820,
#   4925,
#   5032,
#   5141,
#   5252,
#   5365,
#   5480,
#   5597,
#   5716,
#   5837,
#   5960,
#   6085,
#   6212,
#   6341,
#   6472,
#   6605,
#   6740,
#   6877],
#  [3109,
#   3050,
#   2993,
#   2938,
#   2885,
#   2834,
#   2785,
#   2738,
#   2693,
#   2650,
#   2609,
#   2570,
#   2533,
#   2498,
#   2465,
#   2434,
#   2405,
#   2378,
#   2353,
#   2330,
#   2309,
#   2290,
#   2273,
#   2258,
#   2245,
#   2234,
#   2225,
#   2218,
#   2213,
#   2210,
#   2209,
#   2210,
#   2213,
#   2218,
#   2225,
#   2234,
#   2245,
#   2258,
#   2273,
#   2290,
#   2309,
#   2330,
#   2353,
#   2378,
#   2405,
#   2434,
#   2465,
#   2498,
#   2533,
#   2570,
#   2609,
#   2650,
#   2693,
#   2738,
#   2785,
#   2834,
#   2885,
#   2938,
#   2993,
#   3050,
#   3109,
#   3170,
#   3233,
#   3298,
#   3365,
#   3434,
#   3505,
#   3578,
#   3653,
#   3730,
#   3809,
#   3890,
#   3973,
#   4058,
#   4145,
#   4234,
#   4325,
#   4418,
#   4513,
#   4610,
#   4709,
#   4810,
#   4913,
#   5018,
#   5125,
#   5234,
#   5345,
#   5458,
#   5573,
#   5690,
#   5809,
#   5930,
#   6053,
#   6178,
#   6305,
#   6434,
#   6565,
#   6698,
#   6833,
#   6970],
#  [3204,
#   3145,
#   3088,
#   3033,
#   2980,
#   2929,
#   2880,
#   2833,
#   2788,
#   2745,
#   2704,
#   2665,
#   2628,
#   2593,
#   2560,
#   2529,
#   2500,
#   2473,
#   2448,
#   2425,
#   2404,
#   2385,
#   2368,
#   2353,
#   2340,
#   2329,
#   2320,
#   2313,
#   2308,
#   2305,
#   2304,
#   2305,
#   2308,
#   2313,
#   2320,
#   2329,
#   2340,
#   2353,
#   2368,
#   2385,
#   2404,
#   2425,
#   2448,
#   2473,
#   2500,
#   2529,
#   2560,
#   2593,
#   2628,
#   2665,
#   2704,
#   2745,
#   2788,
#   2833,
#   2880,
#   2929,
#   2980,
#   3033,
#   3088,
#   3145,
#   3204,
#   3265,
#   3328,
#   3393,
#   3460,
#   3529,
#   3600,
#   3673,
#   3748,
#   3825,
#   3904,
#   3985,
#   4068,
#   4153,
#   4240,
#   4329,
#   4420,
#   4513,
#   4608,
#   4705,
#   4804,
#   4905,
#   5008,
#   5113,
#   5220,
#   5329,
#   5440,
#   5553,
#   5668,
#   5785,
#   5904,
#   6025,
#   6148,
#   6273,
#   6400,
#   6529,
#   6660,
#   6793,
#   6928,
#   7065],
#  [3301,
#   3242,
#   3185,
#   3130,
#   3077,
#   3026,
#   2977,
#   2930,
#   2885,
#   2842,
#   2801,
#   2762,
#   2725,
#   2690,
#   2657,
#   2626,
#   2597,
#   2570,
#   2545,
#   2522,
#   2501,
#   2482,
#   2465,
#   2450,
#   2437,
#   2426,
#   2417,
#   2410,
#   2405,
#   2402,
#   2401,
#   2402,
#   2405,
#   2410,
#   2417,
#   2426,
#   2437,
#   2450,
#   2465,
#   2482,
#   2501,
#   2522,
#   2545,
#   2570,
#   2597,
#   2626,
#   2657,
#   2690,
#   2725,
#   2762,
#   2801,
#   2842,
#   2885,
#   2930,
#   2977,
#   3026,
#   3077,
#   3130,
#   3185,
#   3242,
#   3301,
#   3362,
#   3425,
#   3490,
#   3557,
#   3626,
#   3697,
#   3770,
#   3845,
#   3922,
#   4001,
#   4082,
#   4165,
#   4250,
#   4337,
#   4426,
#   4517,
#   4610,
#   4705,
#   4802,
#   4901,
#   5002,
#   5105,
#   5210,
#   5317,
#   5426,
#   5537,
#   5650,
#   5765,
#   5882,
#   6001,
#   6122,
#   6245,
#   6370,
#   6497,
#   6626,
#   6757,
#   6890,
#   7025,
#   7162],
#  [3400,
#   3341,
#   3284,
#   3229,
#   3176,
#   3125,
#   3076,
#   3029,
#   2984,
#   2941,
#   2900,
#   2861,
#   2824,
#   2789,
#   2756,
#   2725,
#   2696,
#   2669,
#   2644,
#   2621,
#   2600,
#   2581,
#   2564,
#   2549,
#   2536,
#   2525,
#   2516,
#   2509,
#   2504,
#   2501,
#   2500,
#   2501,
#   2504,
#   2509,
#   2516,
#   2525,
#   2536,
#   2549,
#   2564,
#   2581,
#   2600,
#   2621,
#   2644,
#   2669,
#   2696,
#   2725,
#   2756,
#   2789,
#   2824,
#   2861,
#   2900,
#   2941,
#   2984,
#   3029,
#   3076,
#   3125,
#   3176,
#   3229,
#   3284,
#   3341,
#   3400,
#   3461,
#   3524,
#   3589,
#   3656,
#   3725,
#   3796,
#   3869,
#   3944,
#   4021,
#   4100,
#   4181,
#   4264,
#   4349,
#   4436,
#   4525,
#   4616,
#   4709,
#   4804,
#   4901,
#   5000,
#   5101,
#   5204,
#   5309,
#   5416,
#   5525,
#   5636,
#   5749,
#   5864,
#   5981,
#   6100,
#   6221,
#   6344,
#   6469,
#   6596,
#   6725,
#   6856,
#   6989,
#   7124,
#   7261],
#  [3501,
#   3442,
#   3385,
#   3330,
#   3277,
#   3226,
#   3177,
#   3130,
#   3085,
#   3042,
#   3001,
#   2962,
#   2925,
#   2890,
#   2857,
#   2826,
#   2797,
#   2770,
#   2745,
#   2722,
#   2701,
#   2682,
#   2665,
#   2650,
#   2637,
#   2626,
#   2617,
#   2610,
#   2605,
#   2602,
#   2601,
#   2602,
#   2605,
#   2610,
#   2617,
#   2626,
#   2637,
#   2650,
#   2665,
#   2682,
#   2701,
#   2722,
#   2745,
#   2770,
#   2797,
#   2826,
#   2857,
#   2890,
#   2925,
#   2962,
#   3001,
#   3042,
#   3085,
#   3130,
#   3177,
#   3226,
#   3277,
#   3330,
#   3385,
#   3442,
#   3501,
#   3562,
#   3625,
#   3690,
#   3757,
#   3826,
#   3897,
#   3970,
#   4045,
#   4122,
#   4201,
#   4282,
#   4365,
#   4450,
#   4537,
#   4626,
#   4717,
#   4810,
#   4905,
#   5002,
#   5101,
#   5202,
#   5305,
#   5410,
#   5517,
#   5626,
#   5737,
#   5850,
#   5965,
#   6082,
#   6201,
#   6322,
#   6445,
#   6570,
#   6697,
#   6826,
#   6957,
#   7090,
#   7225,
#   7362],
#  [3604,
#   3545,
#   3488,
#   3433,
#   3380,
#   3329,
#   3280,
#   3233,
#   3188,
#   3145,
#   3104,
#   3065,
#   3028,
#   2993,
#   2960,
#   2929,
#   2900,
#   2873,
#   2848,
#   2825,
#   2804,
#   2785,
#   2768,
#   2753,
#   2740,
#   2729,
#   2720,
#   2713,
#   2708,
#   2705,
#   2704,
#   2705,
#   2708,
#   2713,
#   2720,
#   2729,
#   2740,
#   2753,
#   2768,
#   2785,
#   2804,
#   2825,
#   2848,
#   2873,
#   2900,
#   2929,
#   2960,
#   2993,
#   3028,
#   3065,
#   3104,
#   3145,
#   3188,
#   3233,
#   3280,
#   3329,
#   3380,
#   3433,
#   3488,
#   3545,
#   3604,
#   3665,
#   3728,
#   3793,
#   3860,
#   3929,
#   4000,
#   4073,
#   4148,
#   4225,
#   4304,
#   4385,
#   4468,
#   4553,
#   4640,
#   4729,
#   4820,
#   4913,
#   5008,
#   5105,
#   5204,
#   5305,
#   5408,
#   5513,
#   5620,
#   5729,
#   5840,
#   5953,
#   6068,
#   6185,
#   6304,
#   6425,
#   6548,
#   6673,
#   6800,
#   6929,
#   7060,
#   7193,
#   7328,
#   7465],
#  [3709,
#   3650,
#   3593,
#   3538,
#   3485,
#   3434,
#   3385,
#   3338,
#   3293,
# ...
#   4909,
#   4904,
#   4901,
#   4900,
#   4901,
#   4904,
#   4909,
#   4916,
#   4925,
#   4936,
#   4949,
#   4964,
#   4981,
#   5000,
#   5021,
#   5044,
#   5069,
#   5096,
#   5125,
#   5156,
#   5189,
#   5224,
#   5261,
#   5300,
#   5341,
#   5384,
#   5429,
#   5476,
#   5525,
#   5576,
#   5629,
#   5684,
#   5741,
#   5800,
#   5861,
#   5924,
#   5989,
#   6056,
#   6125,
#   6196,
#   6269,
#   6344,
#   6421,
#   6500,
#   6581,
#   6664,
#   6749,
#   6836,
#   6925,
#   7016,
#   7109,
#   7204,
#   7301,
#   7400,
#   7501,
#   7604,
#   7709,
#   7816,
#   7925,
#   8036,
#   8149,
#   8264,
#   8381,
#   8500,
#   8621,
#   8744,
#   8869,
#   8996,
#   9125,
#   9256,
#   9389,
#   9524,
#   9661],
#  [5941,
#   5882,
#   5825,
#   5770,
#   5717,
#   5666,
#   5617,
#   5570,
#   5525,
#   5482,
#   5441,
#   5402,
#   5365,
#   5330,
#   5297,
#   5266,
#   5237,
#   5210,
#   5185,
#   5162,
#   5141,
#   5122,
#   5105,
#   5090,
#   5077,
#   5066,
#   5057,
#   5050,
#   5045,
#   5042,
#   5041,
#   5042,
#   5045,
#   5050,
#   5057,
#   5066,
#   5077,
#   5090,
#   5105,
#   5122,
#   5141,
#   5162,
#   5185,
#   5210,
#   5237,
#   5266,
#   5297,
#   5330,
#   5365,
#   5402,
#   5441,
#   5482,
#   5525,
#   5570,
#   5617,
#   5666,
#   5717,
#   5770,
#   5825,
#   5882,
#   5941,
#   6002,
#   6065,
#   6130,
#   6197,
#   6266,
#   6337,
#   6410,
#   6485,
#   6562,
#   6641,
#   6722,
#   6805,
#   6890,
#   6977,
#   7066,
#   7157,
#   7250,
#   7345,
#   7442,
#   7541,
#   7642,
#   7745,
#   7850,
#   7957,
#   8066,
#   8177,
#   8290,
#   8405,
#   8522,
#   8641,
#   8762,
#   8885,
#   9010,
#   9137,
#   9266,
#   9397,
#   9530,
#   9665,
#   9802],
#  [6084,
#   6025,
#   5968,
#   5913,
#   5860,
#   5809,
#   5760,
#   5713,
#   5668,
#   5625,
#   5584,
#   5545,
#   5508,
#   5473,
#   5440,
#   5409,
#   5380,
#   5353,
#   5328,
#   5305,
#   5284,
#   5265,
#   5248,
#   5233,
#   5220,
#   5209,
#   5200,
#   5193,
#   5188,
#   5185,
#   5184,
#   5185,
#   5188,
#   5193,
#   5200,
#   5209,
#   5220,
#   5233,
#   5248,
#   5265,
#   5284,
#   5305,
#   5328,
#   5353,
#   5380,
#   5409,
#   5440,
#   5473,
#   5508,
#   5545,
#   5584,
#   5625,
#   5668,
#   5713,
#   5760,
#   5809,
#   5860,
#   5913,
#   5968,
#   6025,
#   6084,
#   6145,
#   6208,
#   6273,
#   6340,
#   6409,
#   6480,
#   6553,
#   6628,
#   6705,
#   6784,
#   6865,
#   6948,
#   7033,
#   7120,
#   7209,
#   7300,
#   7393,
#   7488,
#   7585,
#   7684,
#   7785,
#   7888,
#   7993,
#   8100,
#   8209,
#   8320,
#   8433,
#   8548,
#   8665,
#   8784,
#   8905,
#   9028,
#   9153,
#   9280,
#   9409,
#   9540,
#   9673,
#   9808,
#   9945],
#  [6229,
#   6170,
#   6113,
#   6058,
#   6005,
#   5954,
#   5905,
#   5858,
#   5813,
#   5770,
#   5729,
#   5690,
#   5653,
#   5618,
#   5585,
#   5554,
#   5525,
#   5498,
#   5473,
#   5450,
#   5429,
#   5410,
#   5393,
#   5378,
#   5365,
#   5354,
#   5345,
#   5338,
#   5333,
#   5330,
#   5329,
#   5330,
#   5333,
#   5338,
#   5345,
#   5354,
#   5365,
#   5378,
#   5393,
#   5410,
#   5429,
#   5450,
#   5473,
#   5498,
#   5525,
#   5554,
#   5585,
#   5618,
#   5653,
#   5690,
#   5729,
#   5770,
#   5813,
#   5858,
#   5905,
#   5954,
#   6005,
#   6058,
#   6113,
#   6170,
#   6229,
#   6290,
#   6353,
#   6418,
#   6485,
#   6554,
#   6625,
#   6698,
#   6773,
#   6850,
#   6929,
#   7010,
#   7093,
#   7178,
#   7265,
#   7354,
#   7445,
#   7538,
#   7633,
#   7730,
#   7829,
#   7930,
#   8033,
#   8138,
#   8245,
#   8354,
#   8465,
#   8578,
#   8693,
#   8810,
#   8929,
#   9050,
#   9173,
#   9298,
#   9425,
#   9554,
#   9685,
#   9818,
#   9953,
#   10090],
#  [6376,
#   6317,
#   6260,
#   6205,
#   6152,
#   6101,
#   6052,
#   6005,
#   5960,
#   5917,
#   5876,
#   5837,
#   5800,
#   5765,
#   5732,
#   5701,
#   5672,
#   5645,
#   5620,
#   5597,
#   5576,
#   5557,
#   5540,
#   5525,
#   5512,
#   5501,
#   5492,
#   5485,
#   5480,
#   5477,
#   5476,
#   5477,
#   5480,
#   5485,
#   5492,
#   5501,
#   5512,
#   5525,
#   5540,
#   5557,
#   5576,
#   5597,
#   5620,
#   5645,
#   5672,
#   5701,
#   5732,
#   5765,
#   5800,
#   5837,
#   5876,
#   5917,
#   5960,
#   6005,
#   6052,
#   6101,
#   6152,
#   6205,
#   6260,
#   6317,
#   6376,
#   6437,
#   6500,
#   6565,
#   6632,
#   6701,
#   6772,
#   6845,
#   6920,
#   6997,
#   7076,
#   7157,
#   7240,
#   7325,
#   7412,
#   7501,
#   7592,
#   7685,
#   7780,
#   7877,
#   7976,
#   8077,
#   8180,
#   8285,
#   8392,
#   8501,
#   8612,
#   8725,
#   8840,
#   8957,
#   9076,
#   9197,
#   9320,
#   9445,
#   9572,
#   9701,
#   9832,
#   9965,
#   10100,
#   10237],
#  [6525,
#   6466,
#   6409,
#   6354,
#   6301,
#   6250,
#   6201,
#   6154,
#   6109,
#   6066,
#   6025,
#   5986,
#   5949,
#   5914,
#   5881,
#   5850,
#   5821,
#   5794,
#   5769,
#   5746,
#   5725,
#   5706,
#   5689,
#   5674,
#   5661,
#   5650,
#   5641,
#   5634,
#   5629,
#   5626,
#   5625,
#   5626,
#   5629,
#   5634,
#   5641,
#   5650,
#   5661,
#   5674,
#   5689,
#   5706,
#   5725,
#   5746,
#   5769,
#   5794,
#   5821,
#   5850,
#   5881,
#   5914,
#   5949,
#   5986,
#   6025,
#   6066,
#   6109,
#   6154,
#   6201,
#   6250,
#   6301,
#   6354,
#   6409,
#   6466,
#   6525,
#   6586,
#   6649,
#   6714,
#   6781,
#   6850,
#   6921,
#   6994,
#   7069,
#   7146,
#   7225,
#   7306,
#   7389,
#   7474,
#   7561,
#   7650,
#   7741,
#   7834,
#   7929,
#   8026,
#   8125,
#   8226,
#   8329,
#   8434,
#   8541,
#   8650,
#   8761,
#   8874,
#   8989,
#   9106,
#   9225,
#   9346,
#   9469,
#   9594,
#   9721,
#   9850,
#   9981,
#   10114,
#   10249,
#   10386],
#  [6676,
#   6617,
#   6560,
#   6505,
#   6452,
#   6401,
#   6352,
#   6305,
#   6260,
#   6217,
#   6176,
#   6137,
#   6100,
#   6065,
#   6032,
#   6001,
#   5972,
#   5945,
#   5920,
#   5897,
#   5876,
#   5857,
#   5840,
#   5825,
#   5812,
#   5801,
#   5792,
#   5785,
#   5780,
#   5777,
#   5776,
#   5777,
#   5780,
#   5785,
#   5792,
#   5801,
#   5812,
#   5825,
#   5840,
#   5857,
#   5876,
#   5897,
#   5920,
#   5945,
#   5972,
#   6001,
#   6032,
#   6065,
#   6100,
#   6137,
#   6176,
#   6217,
#   6260,
#   6305,
#   6352,
#   6401,
#   6452,
#   6505,
#   6560,
#   6617,
#   6676,
#   6737,
#   6800,
#   6865,
#   6932,
#   7001,
#   7072,
#   7145,
#   7220,
#   7297,
#   7376,
#   7457,
#   7540,
#   7625,
#   7712,
#   7801,
#   7892,
#   7985,
#   8080,
#   8177,
#   8276,
#   8377,
#   8480,
#   8585,
#   8692,
#   8801,
#   8912,
#   9025,
#   9140,
#   9257,
#   9376,
#   9497,
#   9620,
#   9745,
#   9872,
#   10001,
#   10132,
#   10265,
#   10400,
#   10537],
#  [6829,
#   6770,
#   6713,
#   6658,
#   6605,
#   6554,
#   6505,
#   6458,
#   6413,
#   6370,
#   6329,
#   6290,
#   6253,
#   6218,
#   6185,
#   6154,
#   6125,
#   6098,
#   6073,
#   6050,
#   6029,
#   6010,
#   5993,
#   5978,
#   5965,
#   5954,
#   5945,
#   5938,
#   5933,
#   5930,
#   5929,
#   5930,
#   5933,
#   5938,
#   5945,
#   5954,
#   5965,
#   5978,
#   5993,
#   6010,
#   6029,
#   6050,
#   6073,
#   6098,
#   6125,
#   6154,
#   6185,
#   6218,
#   6253,
#   6290,
#   6329,
#   6370,
#   6413,
#   6458,
#   6505,
#   6554,
#   6605,
#   6658,
#   6713,
#   6770,
#   6829,
#   6890,
#   6953,
#   7018,
#   7085,
#   7154,
#   7225,
#   7298,
#   7373,
#   7450,
#   7529,
#   7610,
#   7693,
#   7778,
#   7865,
#   7954,
#   8045,
#   8138,
#   8233,
#   8330,
#   8429,
#   8530,
#   8633,
#   8738,
#   8845,
#   8954,
#   9065,
#   9178,
#   9293,
#   9410,
#   9529,
#   9650,
#   9773,
#   9898,
#   10025,
#   10154,
#   10285,
#   10418,
#   10553,
#   10690],
#  [6984,
#   6925,
#   6868,
#   6813,
#   6760,
#   6709,
#   6660,
#   6613,
#   6568,
#   6525,
#   6484,
#   6445,
#   6408,
#   6373,
#   6340,
#   6309,
#   6280,
#   6253,
#   6228,
#   6205,
#   6184,
#   6165,
#   6148,
#   6133,
#   6120,
#   6109,
#   6100,
#   6093,
#   6088,
#   6085,
#   6084,
#   6085,
#   6088,
#   6093,
#   6100,
#   6109,
#   6120,
#   6133,
#   6148,
#   6165,
#   6184,
#   6205,
#   6228,
#   6253,
#   6280,
#   6309,
#   6340,
#   6373,
#   6408,
#   6445,
#   6484,
#   6525,
#   6568,
#   6613,
#   6660,
#   6709,
#   6760,
#   6813,
#   6868,
#   6925,
#   6984,
#   7045,
#   7108,
#   7173,
#   7240,
#   7309,
#   7380,
#   7453,
#   7528,
#   7605,
#   7684,
#   7765,
#   7848,
#   7933,
#   8020,
#   8109,
#   8200,
#   8293,
#   8388,
#   8485,
#   8584,
#   8685,
#   8788,
#   8893,
#   9000,
#   9109,
#   9220,
#   9333,
#   9448,
#   9565,
#   9684,
#   9805,
#   9928,
#   10053,
#   10180,
#   10309,
#   10440,
#   10573,
#   10708,
#   10845],
#  [7141,
#   7082,
#   7025,
#   6970,
#   6917,
#   6866,
#   6817,
#   6770,
#   6725,
#   6682,
#   6641,
#   6602,
#   6565,
#   6530,
#   6497,
#   6466,
#   6437,
#   6410,
#   6385,
#   6362,
#   6341,
#   6322,
#   6305,
#   6290,
#   6277,
#   6266,
#   6257,
#   6250,
#   6245,
#   6242,
#   6241,
#   6242,
#   6245,
#   6250,
#   6257,
#   6266,
#   6277,
#   6290,
#   6305,
#   6322,
#   6341,
#   6362,
#   6385,
#   6410,
#   6437,
#   6466,
#   6497,
#   6530,
#   6565,
#   6602,
#   6641,
#   6682,
#   6725,
#   6770,
#   6817,
#   6866,
#   6917,
#   6970,
#   7025,
#   7082,
#   7141,
#   7202,
#   7265,
#   7330,
#   7397,
#   7466,
#   7537,
#   7610,
#   7685,
#   7762,
#   7841,
#   7922,
#   8005,
#   8090,
#   8177,
#   8266,
#   8357,
#   8450,
#   8545,
#   8642,
#   8741,
#   8842,
#   8945,
#   9050,
#   9157,
#   9266,
#   9377,
#   9490,
#   9605,
#   9722,
#   9841,
#   9962,
#   10085,
#   10210,
#   10337,
#   10466,
#   10597,
#   10730,
#   10865,
#   11002],
#  [7300,
#   7241,
#   7184,
#   7129,
#   7076,
#   7025,
#   6976,
#   6929,
#   6884,
#   6841,
#   6800,
#   6761,
#   6724,
#   6689,
#   6656,
#   6625,
#   6596,
#   6569,
#   6544,
#   6521,
#   6500,
#   6481,
#   6464,
#   6449,
#   6436,
#   6425,
#   6416,
#   6409,
#   6404,
#   6401,
#   6400,
#   6401,
#   6404,
#   6409,
#   6416,
#   6425,
#   6436,
#   6449,
#   6464,
#   6481,
#   6500,
#   6521,
#   6544,
#   6569,
#   6596,
#   6625,
#   6656,
#   6689,
#   6724,
#   6761,
#   6800,
#   6841,
#   6884,
#   6929,
#   6976,
#   7025,
#   7076,
#   7129,
#   7184,
#   7241,
#   7300,
#   7361,
#   7424,
#   7489,
#   7556,
#   7625,
#   7696,
#   7769,
#   7844,
#   7921,
#   8000,
#   8081,
#   8164,
#   8249,
#   8336,
#   8425,
#   8516,
#   8609,
#   8704,
#   8801,
#   8900,
#   9001,
#   9104,
#   9209,
#   9316,
#   9425,
#   9536,
#   9649,
#   9764,
#   9881,
#   10000,
#   10121,
#   10244,
#   10369,
#   10496,
#   10625,
#   10756,
#   10889,
#   11024,
#   11161],
#  [7461,
#   7402,
#   7345,
#   7290,
#   7237,
#   7186,
#   7137,
#   7090,
#   7045,
#   7002,
#   6961,
#   6922,
#   6885,
#   6850,
#   6817,
#   6786,
#   6757,
#   6730,
#   6705,
#   6682,
#   6661,
#   6642,
#   6625,
#   6610,
#   6597,
#   6586,
#   6577,
#   6570,
#   6565,
#   6562,
#   6561,
#   6562,
#   6565,
#   6570,
#   6577,
#   6586,
#   6597,
#   6610,
#   6625,
#   6642,
#   6661,
#   6682,
#   6705,
#   6730,
#   6757,
#   6786,
#   6817,
#   6850,
#   6885,
#   6922,
#   6961,
#   7002,
#   7045,
#   7090,
#   7137,
#   7186,
#   7237,
#   7290,
#   7345,
#   7402,
#   7461,
#   7522,
#   7585,
#   7650,
#   7717,
#   7786,
#   7857,
#   7930,
#   8005,
#   8082,
#   8161,
#   8242,
#   8325,
#   8410,
#   8497,
#   8586,
#   8677,
#   8770,
#   8865,
#   8962,
#   9061,
#   9162,
#   9265,
#   9370,
#   9477,
#   9586,
#   9697,
#   9810,
#   9925,
#   10042,
#   10161,
#   10282,
#   10405,
#   10530,
#   10657,
#   10786,
#   10917,
#   11050,
#   11185,
#   11322],
#  [7624,
#   7565,
#   7508,
#   7453,
#   7400,
#   7349,
#   7300,
#   7253,
#   7208,
#   7165,
#   7124,
#   7085,
#   7048,
#   7013,
#   6980,
#   6949,
#   6920,
#   6893,
#   6868,
#   6845,
#   6824,
#   6805,
#   6788,
#   6773,
#   6760,
#   6749,
#   6740,
#   6733,
#   6728,
#   6725,
#   6724,
#   6725,
#   6728,
#   6733,
#   6740,
#   6749,
#   6760,
#   6773,
#   6788,
#   6805,
#   6824,
#   6845,
#   6868,
#   6893,
#   6920,
#   6949,
#   6980,
#   7013,
#   7048,
#   7085,
#   7124,
#   7165,
#   7208,
#   7253,
#   7300,
#   7349,
#   7400,
#   7453,
#   7508,
#   7565,
#   7624,
#   7685,
#   7748,
#   7813,
#   7880,
#   7949,
#   8020,
#   8093,
#   8168,
#   8245,
#   8324,
#   8405,
#   8488,
#   8573,
#   8660,
#   8749,
#   8840,
#   8933,
#   9028,
#   9125,
#   9224,
#   9325,
#   9428,
#   9533,
#   9640,
#   9749,
#   9860,
#   9973,
#   10088,
#   10205,
#   10324,
#   10445,
#   10568,
#   10693,
#   10820,
#   10949,
#   11080,
#   11213,
#   11348,
#   11485],
#  [7789,
#   7730,
#   7673,
#   7618,
#   7565,
#   7514,
#   7465,
#   7418,
#   7373,
#   7330,
#   7289,
#   7250,
#   7213,
#   7178,
#   7145,
#   7114,
#   7085,
#   7058,
#   7033,
#   7010,
#   6989,
#   6970,
#   6953,
#   6938,
#   6925,
#   6914,
#   6905,
#   6898,
#   6893,
#   6890,
#   6889,
#   6890,
#   6893,
#   6898,
#   6905,
#   6914,
#   6925,
#   6938,
#   6953,
#   6970,
#   6989,
#   7010,
#   7033,
#   7058,
#   7085,
#   7114,
#   7145,
#   7178,
#   7213,
#   7250,
#   7289,
#   7330,
#   7373,
#   7418,
#   7465,
#   7514,
#   7565,
#   7618,
#   7673,
#   7730,
#   7789,
#   7850,
#   7913,
#   7978,
#   8045,
#   8114,
#   8185,
#   8258,
#   8333,
#   8410,
#   8489,
#   8570,
#   8653,
#   8738,
#   8825,
#   8914,
#   9005,
#   9098,
#   9193,
#   9290,
#   9389,
#   9490,
#   9593,
#   9698,
#   9805,
#   9914,
#   10025,
#   10138,
#   10253,
#   10370,
#   10489,
#   10610,
#   10733,
#   10858,
#   10985,
#   11114,
#   11245,
#   11378,
#   11513,
#   11650],
#  [7956,
#   7897,
#   7840,
#   7785,
#   7732,
#   7681,
#   7632,
#   7585,
#   7540,
#   7497,
#   7456,
#   7417,
#   7380,
#   7345,
#   7312,
#   7281,
#   7252,
#   7225,
#   7200,
#   7177,
#   7156,
#   7137,
#   7120,
#   7105,
#   7092,
#   7081,
#   7072,
#   7065,
#   7060,
#   7057,
#   7056,
#   7057,
#   7060,
#   7065,
#   7072,
#   7081,
#   7092,
#   7105,
#   7120,
#   7137,
#   7156,
#   7177,
#   7200,
#   7225,
#   7252,
#   7281,
#   7312,
#   7345,
#   7380,
#   7417,
#   7456,
#   7497,
#   7540,
#   7585,
#   7632,
#   7681,
#   7732,
#   7785,
#   7840,
#   7897,
#   7956,
#   8017,
#   8080,
#   8145,
#   8212,
#   8281,
#   8352,
#   8425,
#   8500,
#   8577,
#   8656,
#   8737,
#   8820,
#   8905,
#   8992,
#   9081,
#   9172,
#   9265,
#   9360,
#   9457,
#   9556,
#   9657,
#   9760,
#   9865,
#   9972,
#   10081,
#   10192,
#   10305,
#   10420,
#   10537,
#   10656,
#   10777,
#   10900,
#   11025,
#   11152,
#   11281,
#   11412,
#   11545,
#   11680,
#   11817],
#  [8125,
#   8066,
#   8009,
#   7954,
#   7901,
#   7850,
#   7801,
#   7754,
#   7709,
#   7666,
#   7625,
#   7586,
#   7549,
#   7514,
#   7481,
#   7450,
#   7421,
#   7394,
#   7369,
#   7346,
#   7325,
#   7306,
#   7289,
#   7274,
#   7261,
#   7250,
#   7241,
#   7234,
#   7229,
#   7226,
#   7225,
#   7226,
#   7229,
#   7234,
#   7241,
#   7250,
#   7261,
#   7274,
#   7289,
#   7306,
#   7325,
#   7346,
#   7369,
#   7394,
#   7421,
#   7450,
#   7481,
#   7514,
#   7549,
#   7586,
#   7625,
#   7666,
#   7709,
#   7754,
#   7801,
#   7850,
#   7901,
#   7954,
#   8009,
#   8066,
#   8125,
#   8186,
#   8249,
#   8314,
#   8381,
#   8450,
#   8521,
#   8594,
#   8669,
#   8746,
#   8825,
#   8906,
#   8989,
#   9074,
#   9161,
#   9250,
#   9341,
#   9434,
#   9529,
#   9626,
#   9725,
#   9826,
#   9929,
#   10034,
#   10141,
#   10250,
#   10361,
#   10474,
#   10589,
#   10706,
#   10825,
#   10946,
#   11069,
#   11194,
#   11321,
#   11450,
#   11581,
#   11714,
#   11849,
#   11986],
#  [8296,
#   8237,
#   8180,
#   8125,
#   8072,
#   8021,
#   7972,
#   7925,
#   7880,
#   7837,
#   7796,
#   7757,
#   7720,
#   7685,
#   7652,
#   7621,
#   7592,
#   7565,
#   7540,
#   7517,
#   7496,
#   7477,
#   7460,
#   7445,
#   7432,
#   7421,
#   7412,
#   7405,
#   7400,
#   7397,
#   7396,
#   7397,
#   7400,
#   7405,
#   7412,
#   7421,
#   7432,
#   7445,
#   7460,
#   7477,
#   7496,
#   7517,
#   7540,
#   7565,
#   7592,
#   7621,
#   7652,
#   7685,
#   7720,
#   7757,
#   7796,
#   7837,
#   7880,
#   7925,
#   7972,
#   8021,
#   8072,
#   8125,
#   8180,
#   8237,
#   8296,
#   8357,
#   8420,
#   8485,
#   8552,
#   8621,
#   8692,
#   8765,
#   8840,
#   8917,
#   8996,
#   9077,
#   9160,
#   9245,
#   9332,
#   9421,
#   9512,
#   9605,
#   9700,
#   9797,
#   9896,
#   9997,
#   10100,
#   10205,
#   10312,
#   10421,
#   10532,
#   10645,
#   10760,
#   10877,
#   10996,
#   11117,
#   11240,
#   11365,
#   11492,
#   11621,
#   11752,
#   11885,
#   12020,
#   12157],
#  [8469,
#   8410,
#   8353,
#   8298,
#   8245,
#   8194,
#   8145,
#   8098,
#   8053,
#   8010,
#   7969,
#   7930,
#   7893,
#   7858,
#   7825,
#   7794,
#   7765,
#   7738,
#   7713,
#   7690,
#   7669,
#   7650,
#   7633,
#   7618,
#   7605,
#   7594,
#   7585,
#   7578,
#   7573,
#   7570,
#   7569,
#   7570,
#   7573,
#   7578,
#   7585,
#   7594,
#   7605,
#   7618,
#   7633,
#   7650,
#   7669,
#   7690,
#   7713,
#   7738,
#   7765,
#   7794,
#   7825,
#   7858,
#   7893,
#   7930,
#   7969,
#   8010,
#   8053,
#   8098,
#   8145,
#   8194,
#   8245,
#   8298,
#   8353,
#   8410,
#   8469,
#   8530,
#   8593,
#   8658,
#   8725,
#   8794,
#   8865,
#   8938,
#   9013,
#   9090,
#   9169,
#   9250,
#   9333,
#   9418,
#   9505,
#   9594,
#   9685,
#   9778,
#   9873,
#   9970,
#   10069,
#   10170,
#   10273,
#   10378,
#   10485,
#   10594,
#   10705,
#   10818,
#   10933,
#   11050,
#   11169,
#   11290,
#   11413,
#   11538,
#   11665,
#   11794,
#   11925,
#   12058,
#   12193,
#   12330],
#  [8644,
#   8585,
#   8528,
#   8473,
#   8420,
#   8369,
#   8320,
#   8273,
#   8228,
#   8185,
#   8144,
#   8105,
#   8068,
#   8033,
#   8000,
#   7969,
#   7940,
#   7913,
#   7888,
#   7865,
#   7844,
#   7825,
#   7808,
#   7793,
#   7780,
#   7769,
#   7760,
#   7753,
#   7748,
#   7745,
#   7744,
#   7745,
#   7748,
#   7753,
#   7760,
#   7769,
#   7780,
#   7793,
#   7808,
#   7825,
#   7844,
#   7865,
#   7888,
#   7913,
#   7940,
#   7969,
#   8000,
#   8033,
#   8068,
#   8105,
#   8144,
#   8185,
#   8228,
#   8273,
#   8320,
#   8369,
#   8420,
#   8473,
#   8528,
#   8585,
#   8644,
#   8705,
#   8768,
#   8833,
#   8900,
#   8969,
#   9040,
#   9113,
#   9188,
#   9265,
#   9344,
#   9425,
#   9508,
#   9593,
#   9680,
#   9769,
#   9860,
#   9953,
#   10048,
#   10145,
#   10244,
#   10345,
#   10448,
#   10553,
#   10660,
#   10769,
#   10880,
#   10993,
#   11108,
#   11225,
#   11344,
#   11465,
#   11588,
#   11713,
#   11840,
#   11969,
#   12100,
#   12233,
#   12368,
#   12505],
#  [8821,
#   8762,
#   8705,
#   8650,
#   8597,
#   8546,
#   8497,
#   8450,
#   8405,
#   8362,
#   8321,
#   8282,
#   8245,
#   8210,
#   8177,
#   8146,
#   8117,
#   8090,
#   8065,
#   8042,
#   8021,
#   8002,
#   7985,
#   7970,
#   7957,
#   7946,
#   7937,
#   7930,
#   7925,
#   7922,
#   7921,
#   7922,
#   7925,
#   7930,
#   7937,
#   7946,
#   7957,
#   7970,
#   7985,
#   8002,
#   8021,
#   8042,
#   8065,
#   8090,
#   8117,
#   8146,
#   8177,
#   8210,
#   8245,
#   8282,
#   8321,
#   8362,
#   8405,
#   8450,
#   8497,
#   8546,
#   8597,
#   8650,
#   8705,
#   8762,
#   8821,
#   8882,
#   8945,
#   9010,
#   9077,
#   9146,
#   9217,
#   9290,
#   9365,
#   9442,
#   9521,
#   9602,
#   9685,
#   9770,
#   9857,
#   9946,
#   10037,
#   10130,
#   10225,
#   10322,
#   10421,
#   10522,
#   10625,
#   10730,
#   10837,
#   10946,
#   11057,
#   11170,
#   11285,
#   11402,
#   11521,
#   11642,
#   11765,
#   11890,
#   12017,
#   12146,
#   12277,
#   12410,
#   12545,
#   12682]]

# %%
plt.imshow(a, origin='lower', cmap='gray_r')
plt.colorbar()

# %%
x = np.arange(-1, 1, 0.1)
y = np.arange(-1, 1, 0.1)

xx, yy = np.meshgrid(x,y)
xx.shape, yy.shape
# Out:
# ((20, 20), (20, 20))

# %%
zz = np.sin(xx*yy)
plt.imshow(zz, origin='lower')
plt.colorbar()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
zz = xx*yy
plt.imshow(zz, origin='lower')
plt.colorbar()

# %%
import matplotlib.image as mpimg

img=mpimg.imread('aaron.jpg')
display(img.shape)
# Out:
# (250, 250, 3)

# %%
img = plt.imread('aaron.jpg')
plt.imshow(img)

# %%
img.max(), img.min()
# Out:
# (239, 0)

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,0], vmin=0, vmax=255, cmap='Reds_r')

# %%
plt.imshow(img[:,:,1], vmin=0, vmax=255, cmap='Greens')

# %%
plt.imshow(img[:,:,2], vmin=0, vmax=255, cmap='Blues')

# %%
a = np.zeros([100,100])
b = np.zeros([100,100])
c = np.zeros([100,100])

a[30:60,30:60] = 1
b[40:80,40:80] = 1
c[50:90,20:70] = 1
d = np.zeros([100,100,3])

d[:,:,0] = a
d[:,:,1] = b
d[:,:,2] = c

plt.imshow(d)

# %% [markdown]
# ### 등고선
# - 이차원 평면 상에서 등고선을 그린다.

# %%
x = np.arange(-1,1,0.1)
y = np.arange(-1,1,0.1)

xx, yy = np.meshgrid(x,y)

zz = np.sin(xx*yy)
#plt.imshow(zz)
CS = plt.contour(xx, yy, zz, levels=np.arange(-1,1,0.2)) # plt.contour(zz)
plt.clabel(CS, inline=2, fontsize=10)
plt.colorbar()

# %%
x = np.arange(-1,1,0.1)
y = np.arange(-1,1,0.1)

xx, yy = np.meshgrid(x,y)

zz = np.sin(xx*yy)
plt.contourf(xx, yy, zz, levels=np.arange(-1,1,0.2),alpha=0.5)
CS = plt.contour(xx, yy, zz, levels=np.arange(-1,1,0.2)) # plt.contour(zz)
plt.clabel(CS, inline=2, fontsize=10)
plt.colorbar()

# %% [markdown]
# ### cmap
# - 플롯의 색상 범위를 지정한다.
# - https://matplotlib.org/examples/color/colormaps_reference.html
# - 플롯에서 사용한 값에 따라 자동으로 색상영역을 잡는다. (imshow 의 vmin, vmax 참고)

# %% [markdown]
# ### 여러개의 플롯을 한번에 그리기

# %%
fig, axes = plt.subplots(2,2, figsize=[10,8])
display(axes.shape)

axes[0,0].plot([1,2,3,4])
axes[0,1].scatter(np.random.randn(100), np.random.randn(100))
axes[1,0].bar(range(10),range(10))
axes[1,1].imshow(np.random.randn(64,64))

fig.suptitle('TEST', fontsize=20)
axes[0,0].set_title('TEST1')
# Out:
# (2, 2)
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
fig = plt.figure(figsize=[10,8])
fig.suptitle('TEST', fontsize=20)

plt.subplot(2,2,1)
plt.title('TEST1')
plt.plot([0,1,2,3])

plt.subplot(2,2,2)
plt.title('TEST2')
plt.scatter(np.random.randn(100), np.random.randn(100))

plt.subplot(2,2,3)
plt.title('TEST3')
plt.bar(range(10),range(10))

plt.subplot(2,2,4)
plt.title('TEST4')
plt.imshow(np.random.randn(64,64))
plt.colorbar()

plt.savefig('test1.jpg', dpi=200)

# %%
fig, axes = plt.subplots(5,5)
for i in range(25):
    axes[i//5, i%5].plot([1*i,2*i,i*i,4*i])

# %% [markdown]
# ### 텍스트와 화살표 그리기

# %%
plt.axis([-10,10,-10,10])
plt.vlines([0,5,-5],-10,10,linestyles=':')
plt.hlines([0,5,-5],-10,10,linestyles=':')

plt.text(0,0,'안녕하세요',fontproperties=prop,fontsize=20,va='center',ha='center')
plt.annotate('원점',xy=(0,0),xytext=(5,5),arrowprops=dict(facecolor='black'),fontproperties=prop)
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ### 플롯을 파일로 저장

# %%
x = np.arange(-1,1,0.1)
y = np.arange(-1,1,0.1)

xx, yy = np.meshgrid(x,y)

a = np.sin(xx*yy)
plt.imshow(a, origin='lower')
plt.colorbar()
plt.xticks(range(20),x, rotation=90)

plt.savefig('myplot.jpg',dpi=100)

# %%
plt.plot(np.random.randn(100))
plt.savefig('myplot.jpg',dpi=100)

# %%
plt.plot([1,2,3,4])
plt.axis('off')
# Out:
# (-0.15000000000000002, 3.15, 0.85, 4.15)

# %%
import matplotlib.image as mpimg

img=mpimg.imread('myplot.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 599.5, 399.5, -0.5)

# %% [markdown]
# ### 3차원 그림 맛보기

# %%
from mpl_toolkits.mplot3d import Axes3D, axes3d

fig = plt.figure()
#ax=Axes3D(fig, elev=-152, azim=-26)
ax = Axes3D(fig)

rng = np.arange(-10,10,0.5)
X,Y = np.meshgrid(rng, rng)
#Z = 1 / (1+np.exp(-1*(X+Y)))
Z = X**2 + Y**2

m = ax.scatter(X,Y,Z, s=5, cmap='autumn')
#fig.colorbar(m, shrink=0.7)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# Out:
# Text(0.5,0,'Z')
